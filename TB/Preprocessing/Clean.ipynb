# %%
import pandas as pd

# %%
df = pd.read_csv("Full_Clean.csv")

# %%
df.head()
# Out:
#                        STATE            DISTRICT  QTR    YR  \
# 0  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS    1  2008
# 1             Andhra Pradesh            ADILABAD    1  2008
# 2             Andhra Pradesh           ANANTAPUR    1  2008
# 3             Andhra Pradesh        BHADRACHALAM    1  2008
# 4             Andhra Pradesh            CUDDAPAH    1  2008
#
#    NSP Male/ NewMicConfMale  NSP Female/ NewMicConf Female  \
# 0                        37                             21
# 1                       257                            112
# 2                       529                            181
# 3                       137                             43
# 4                       296                             84
#
#    NSP Total/ NewMicConf Total  Relapse Male  Relapse Female  \
# 0                           58             5               1
# 1                          369            40              21
# ...

# %%
dis = df.groupby('DISTRICT')

# %%
cap = dis.get_group('MURSHIDABAD')

# %%
small = dis.get_group('Murshidabad')

# %%
name = pd.concat([cap , small])

# %%
name.to_csv(r'Downloads/TB/FINAL/Data/West Bengal/Murshidabad.csv' , index =  False)

# %%
name = pd.concat([name , y])

# %%
z = pd.concat([small[:8] , y[:2]])

# %%
z = pd.concat([z , small[8:10]])

# %%
z = pd.concat([z , small[10:14]])

# %%
z = pd.concat([z , small[14:18]])

# %%
small = pd.concat([z , y[2:]])

# %%
name = pd.concat([name , y])

# %%
state = df.groupby("STATE")

# %%
tamil = state.get_group('West Bengal')

# %%
year = tamil.groupby('YR')

# %%
year.get_group(2015).head(40)
# Out:
#              STATE           DISTRICT  QTR    YR  NSP Male/ NewMicConfMale  \
# 18471  West Bengal            Alipore    1  2015                        34
# 18472  West Bengal           Bagbazar    1  2015                        29
# 18473  West Bengal            Bankura    1  2015                       367
# 18474  West Bengal         Barddhaman    1  2015                       768
# 18475  West Bengal             Behala    1  2015                        24
# 18476  West Bengal          Darjiling    1  2015                       152
# 18477  West Bengal              Haora    1  2015                       357
# 18478  West Bengal               Hazi    1  2015                        29
# 18479  West Bengal              Hugli    1  2015                       450
# 18480  West Bengal         Jalpaiguri    1  2015                       491
# 18481  West Bengal         Koch Bihar    1  2015                       214
# ...

# %%
z = dis.get_group('Kolkota')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-373-e532d9b33823> in <module>
# ----> 1 z = dis.get_group('Kolkota')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     684         inds = self._get_index(name)
#     685         if not len(inds):
# --> 686             raise KeyError(name)
#     687
#     688         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: 'Kolkota'

# %%
name = pd.concat([name , z])

# %%
x = name[:22]

# %%
y = name[22:23]

# %%
y['QTR'] = 3
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
y
# Out:
#              STATE DISTRICT  QTR    YR  NSP Male/ NewMicConfMale  \
# 15189  Uttarakhand  Hardwar    3  2013                       103
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 15189                             63                          166
#
#        Relapse Male  Relapse Female  NSN Male/NewClinDiag Male  ...  \
# 15189            38              17                         50  ...
#
#        35-44 yrs NSP(NewAll207+) Male  35-44 yrs NSP(NewAll207+) Female  \
# 15189                            18.0                               7.0
#
#        45-54 yrs NSP(NewAll207+) Male  45-54 yrs NSP(NewAll207+) Female  \
# 15189                            17.0                               6.0
#
#        55-64 yrs NSP(NewAll207+) Male  55-64 yrs NSP(NewAll207+) Female  \
# 15189                            14.0                               4.0
#
#        65 & above yrs NSP(NewAll207+) Male  \
# 15189                                  8.0
#
# ...

# %%
z = pd.concat([x , y])

# %%
z = pd.concat([z , name[22:]])

# %%
name = z
