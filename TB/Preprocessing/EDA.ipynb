# %%
import pandas as pd

# %%
hiv = pd.read_csv('HIV.csv')

# %%
hiv.head()
# Out:
#    Year                      STATE            DISTRICT  SumOfHIV_Tested  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS              0.0
# 1  2008             Andhra Pradesh            ADILABAD            177.0
# 2  2008             Andhra Pradesh           ANANTAPUR            199.0
# 3  2008             Andhra Pradesh        BHADRACHALAM             89.0
# 4  2008             Andhra Pradesh            CUDDAPAH              0.0
#
#    SumOfHIV_infected  Quarter
# 0                0.0        1
# 1               76.0        1
# 2               50.0        1
# 3                7.0        1
# 4                0.0        1

# %%
hiv.shape
# Out:
# (29834, 6)

# %%
dis = hiv.groupby(['DISTRICT'])

# %%
dis.get_group('Uttar Dinajpur')
# Out:
#        Year        STATE        DISTRICT  SumOfHIV_Tested  SumOfHIV_infected  \
# 5573   2010  West Bengal  Uttar Dinajpur              0.0                0.0
# 6203   2010  West Bengal  Uttar Dinajpur            111.0                6.0
# 6834   2010  West Bengal  Uttar Dinajpur            115.0                5.0
# 7469   2010  West Bengal  Uttar Dinajpur            200.0                9.0
# 8111   2011  West Bengal  Uttar Dinajpur            236.0                6.0
# 8753   2011  West Bengal  Uttar Dinajpur            537.0                9.0
# 9397   2011  West Bengal  Uttar Dinajpur            450.0               13.0
# 10041  2011  West Bengal  Uttar Dinajpur            290.0               11.0
# 10682  2012  West Bengal  Uttar Dinajpur            396.0               12.0
# 11326  2012  West Bengal  Uttar Dinajpur            566.0               18.0
# 11970  2012  West Bengal  Uttar Dinajpur            461.0               18.0
# ...

# %%
hiv['Year']
# Out:
# 0        2008
# 1        2008
# 2        2008
# 3        2008
# 4        2008
#          ...
# 29829    2017
# 29830    2018
# 29831    2018
# 29832    2018
# 29833    2018
# Name: Year, Length: 29834, dtype: int64

# %%
hiv.tail()
# Out:
#        Year        STATE        DISTRICT  SumOfHIV_Tested  SumOfHIV_infected  \
# 29829  2017  West Bengal  Uttar Dinajpur            466.0               10.0
# 29830  2018  West Bengal  Uttar Dinajpur            574.0                8.0
# 29831  2018  West Bengal  Uttar Dinajpur            559.0                7.0
# 29832  2018  West Bengal  Uttar Dinajpur            448.0                7.0
# 29833  2018  West Bengal  Uttar Dinajpur            370.0                7.0
#
#        Quarter
# 29829        4
# 29830        1
# 29831        2
# 29832        3
# 29833        4

# %%
hiv['Month'] = hiv['Quarter']  * 3

# %%
hiv.head()
# Out:
#    Year                      STATE            DISTRICT  SumOfHIV_Tested  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS              0.0
# 1  2008             Andhra Pradesh            ADILABAD            177.0
# 2  2008             Andhra Pradesh           ANANTAPUR            199.0
# 3  2008             Andhra Pradesh        BHADRACHALAM             89.0
# 4  2008             Andhra Pradesh            CUDDAPAH              0.0
#
#    SumOfHIV_infected  Quarter  Month
# 0                0.0        1      3
# 1               76.0        1      3
# 2               50.0        1      3
# 3                7.0        1      3
# 4                0.0        1      3

# %%
dis = hiv.groupby(['DISTRICT'])

# %%
dis.get_group('Uttar Dinajpur')
# Out:
#        Year        STATE        DISTRICT  SumOfHIV_Tested  SumOfHIV_infected  \
# 5573   2010  West Bengal  Uttar Dinajpur              0.0                0.0
# 6203   2010  West Bengal  Uttar Dinajpur            111.0                6.0
# 6834   2010  West Bengal  Uttar Dinajpur            115.0                5.0
# 7469   2010  West Bengal  Uttar Dinajpur            200.0                9.0
# 8111   2011  West Bengal  Uttar Dinajpur            236.0                6.0
# 8753   2011  West Bengal  Uttar Dinajpur            537.0                9.0
# 9397   2011  West Bengal  Uttar Dinajpur            450.0               13.0
# 10041  2011  West Bengal  Uttar Dinajpur            290.0               11.0
# 10682  2012  West Bengal  Uttar Dinajpur            396.0               12.0
# 11326  2012  West Bengal  Uttar Dinajpur            566.0               18.0
# 11970  2012  West Bengal  Uttar Dinajpur            461.0               18.0
# ...

# %%
z = pd.to_datetime(['yr' , 'mnth'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1855         try:
# -> 1856             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1857             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-14-eac4c4f518f8> in <module>
# ----> 1 z = pd.to_datetime(['yr' , 'mnth'])
#
# ...

# %%
yr = hiv.drop(['STATE' , 'DISTRICT' , 'SumOfHIV_Tested' , 'SumOfHIV_infected' , 'Quarter'] , axis = 1)

# %%
yr.head()
# Out:
#    Year  Month
# 0  2008      3
# 1  2008      3
# 2  2008      3
# 3  2008      3
# 4  2008      3

# %%
pd.to_datetime(yr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-387ad390a9d7> in <module>
# ----> 1 pd.to_datetime(yr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     729             result = arg._constructor(values, index=arg.index, name=arg.name)
#     730     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# --> 731         result = _assemble_from_unit_mappings(arg, errors, tz)
#     732     elif isinstance(arg, ABCIndexClass):
#     733         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _assemble_from_unit_mappings(arg, errors, tz)
#     830         required = ",".join(req)
#     831         raise ValueError(
# ...

# %%
import numpy as np

# %%
yr.shape
# Out:
# (29834, 2)

# %%
one = np.ones([29834 , 1] , dtype = int)

# %%
one.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-eec5ff3eef75> in <module>
# ----> 1 one.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
yr['Day'] = one

# %%
yr.head()

# %%
hiv['Date'] = pd.to_datetime(yr)

# %%
hiv.head()

# %%
hiv.to_csv(r'Downloads/HIV.csv' , index = False)

# %%
ped = pd.read_csv('Pediatric.csv')

# %%
ped.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-9ba5750ec69d> in <module>
# ----> 1 ped.head()
#
# NameError: name 'ped' is not defined

# %%
ped['Date'] = hiv['Date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-7319575b6a83> in <module>
# ----> 1 ped['Date'] = hiv['Date']
#
# ...

# %%
ped.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-9ba5750ec69d> in <module>
# ----> 1 ped.head()
#
# NameError: name 'ped' is not defined

# %%
ped.to_csv(r'Downloads/Pediatric.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-02eca4d216bd> in <module>
# ----> 1 ped.to_csv(r'Downloads/Pediatric.csv')
#
# NameError: name 'ped' is not defined

# %%
ger = pd.read_csv('Geriatric.csv')

# %%
ger.head()
# Out:
#    Year                      STATE            DISTRICT  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1  2008             Andhra Pradesh            ADILABAD
# 2  2008             Andhra Pradesh           ANANTAPUR
# 3  2008             Andhra Pradesh        BHADRACHALAM
# 4  2008             Andhra Pradesh            CUDDAPAH
#
#    65 & above yrs NSP(NewAll207+) Male  65 & above yrs NSP(NewAll207+) Female  \
# 0                                  2.0                                    2.0
# 1                                 24.0                                    5.0
# 2                                 53.0                                    5.0
# 3                                  5.0                                    4.0
# 4                                 33.0                                    3.0
#
#    Total Geriatric  Quarter
# 0              4.0        1
# 1             29.0        1
# 2             58.0        1
# 3              9.0        1
# ...

# %%
ger['Date'] = hiv['Date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-1c5ef98de6a4> in <module>
# ----> 1 ger['Date'] = hiv['Date']
#
# ...

# %%
ger.head()
# Out:
#    Year                      STATE            DISTRICT  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1  2008             Andhra Pradesh            ADILABAD
# 2  2008             Andhra Pradesh           ANANTAPUR
# 3  2008             Andhra Pradesh        BHADRACHALAM
# 4  2008             Andhra Pradesh            CUDDAPAH
#
#    65 & above yrs NSP(NewAll207+) Male  65 & above yrs NSP(NewAll207+) Female  \
# 0                                  2.0                                    2.0
# 1                                 24.0                                    5.0
# 2                                 53.0                                    5.0
# 3                                  5.0                                    4.0
# 4                                 33.0                                    3.0
#
#    Total Geriatric  Quarter
# 0              4.0        1
# 1             29.0        1
# 2             58.0        1
# 3              9.0        1
# ...

# %%
ger.to_csv(r'Downloads/Geriatric.csv')

# %%
hiv.tail()
# Out:
#        Year        STATE        DISTRICT  SumOfHIV_Tested  SumOfHIV_infected  \
# 29829  2017  West Bengal  Uttar Dinajpur            466.0               10.0
# 29830  2018  West Bengal  Uttar Dinajpur            574.0                8.0
# 29831  2018  West Bengal  Uttar Dinajpur            559.0                7.0
# 29832  2018  West Bengal  Uttar Dinajpur            448.0                7.0
# 29833  2018  West Bengal  Uttar Dinajpur            370.0                7.0
#
#        Quarter  Month
# 29829        4     12
# 29830        1      3
# 29831        2      6
# 29832        3      9
# 29833        4     12

# %%
h = hiv.groupby('DISTRICT')

# %%
 UD = h.get_group('Uttar Dinajpur')

# %%
UD.head()
# Out:
#       Year        STATE        DISTRICT  SumOfHIV_Tested  SumOfHIV_infected  \
# 5573  2010  West Bengal  Uttar Dinajpur              0.0                0.0
# 6203  2010  West Bengal  Uttar Dinajpur            111.0                6.0
# 6834  2010  West Bengal  Uttar Dinajpur            115.0                5.0
# 7469  2010  West Bengal  Uttar Dinajpur            200.0                9.0
# 8111  2011  West Bengal  Uttar Dinajpur            236.0                6.0
#
#       Quarter  Month
# 5573        1      3
# 6203        2      6
# 6834        3      9
# 7469        4     12
# 8111        1      3

# %%
UD
# Out:
#        Year        STATE        DISTRICT  SumOfHIV_Tested  SumOfHIV_infected  \
# 5573   2010  West Bengal  Uttar Dinajpur              0.0                0.0
# 6203   2010  West Bengal  Uttar Dinajpur            111.0                6.0
# 6834   2010  West Bengal  Uttar Dinajpur            115.0                5.0
# 7469   2010  West Bengal  Uttar Dinajpur            200.0                9.0
# 8111   2011  West Bengal  Uttar Dinajpur            236.0                6.0
# 8753   2011  West Bengal  Uttar Dinajpur            537.0                9.0
# 9397   2011  West Bengal  Uttar Dinajpur            450.0               13.0
# 10041  2011  West Bengal  Uttar Dinajpur            290.0               11.0
# 10682  2012  West Bengal  Uttar Dinajpur            396.0               12.0
# 11326  2012  West Bengal  Uttar Dinajpur            566.0               18.0
# 11970  2012  West Bengal  Uttar Dinajpur            461.0               18.0
# ...

# %%
import pmdarima as pm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-05191c3ae93f> in <module>
# ----> 1 import pmdarima as pm
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
# !pip3 install pyramid-arima
# Out:
# ...
#   Using cached pyramid-arima-0.8.1.tar.gz (515 kB)
# ...
#   Using cached scikit_learn-0.23.2-cp38-cp38-win_amd64.whl (6.8 MB)
# ...
#   Using cached pandas-1.1.3-cp38-cp38-win_amd64.whl (8.9 MB)
# ...
#   Using cached statsmodels-0.12.0-cp38-none-win_amd64.whl (9.2 MB)
# ...
#   Using cached pytz-2020.1-py2.py3-none-any.whl (510 kB)
# ...
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# ...
#   Using cached patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# ...
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Using legacy 'setup.py install' for pyramid-arima, since package 'wheel' is not installed.
# ...
# ERROR: Could not install packages due to an EnvironmentError: [Errno 2] No such file or directory: 'C:\\Users\\jayth\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python38\\site-packages\\sklearn\\datasets\\tests\\data\\openml\\292\\api-v1-json-data-list-data_name-australian-limit-2-data_version-1-status-deactivated.json.gz'
#
# ...

# %%
import pmdarima as pm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-05191c3ae93f> in <module>
# ----> 1 import pmdarima as pm
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
sys.path.insert(0, "/usr/local/lib/python3.7/site-packages")

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
UD.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-2a155b3917d6> in <module>
# ----> 1 UD.value
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value'

# %%
model = ARIMA([UD['Date'], UD['SumOfHIV_infected']] , order=(1,1,2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-db43fea4e84f> in <module>
# ...

# %%
UD =UD.drop(['STATE' , 'DISTRICT' , 'Year' , 'Quarter' , 'Month' , 'SumOfHIV_Tested'] , axis = 1)

# %%
model = ARIMA(UD.values, order=(1,1,2))

# %%
import seaborn as sns

# %%
sns.residplot(UD['SumOfHIV_infected'] , UD['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-b6025be2e8cf> in <module>
# ...

# %%
sns.plot(UD)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-65097e2da2a7> in <module>
# ----> 1 sns.plot(UD)
#
# AttributeError: module 'seaborn' has no attribute 'plot'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(UD)

# %%
sns.lineplot(data=UD , x = 'Date' , y = 'SumOfHIV_infected')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-ea83f72b1706> in <module>
# ----> 1 sns.lineplot(data=UD , x = 'Date' , y = 'SumOfHIV_infected')
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1129         dashes=dashes, markers=markers, style_order=style_order,
#    1130         units=units, estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
# -> 1131         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1132     )
#    1133
#
# ...

# %%
rolling_mean = UD.rolling(window = 12).mean()
rolling_std = UD.rolling(window = 12).std()
plt.plot(UD, color = 'blue', label = 'Original')
plt.plot(rolling_mean, color = 'red', label = 'Rolling Mean')
plt.plot(rolling_std, color = 'black', label = 'Rolling Std')
plt.legend(loc = 'best')
plt.title('Rolling Mean & Rolling Standard Deviation')
plt.show()

# %%
UD
# Out:
#        SumOfHIV_infected
# 5573                 0.0
# 6203                 6.0
# 6834                 5.0
# 7469                 9.0
# 8111                 6.0
# 8753                 9.0
# 9397                13.0
# 10041               11.0
# 10682               12.0
# 11326               18.0
# 11970               18.0
# 12614               10.0
# 13258               13.0
# 13903               15.0
# 14556               15.0
# 15214               10.0
# 15871               16.0
# 16535               22.0
# 17200               15.0
# 17866                6.0
# 18496               13.0
# 19212               23.0
# 19950                1.0
# 20673               10.0
# 21185                6.0
# 22072               15.0
# 22908                4.0
# 23667                8.0
# 29826                6.0
# 29827               10.0
# 29828               11.0
# 29829               10.0
# 29830                8.0
# 29831                7.0
# 29832                7.0
# 29833                7.0

# %%
UD['SumOfHIV_infected'] , UD['Date'] == UD['Date'] , UD['SumOfHIV_infected']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-46ab437882c9> in <module>
# ...

# %%
UD
# Out:
#        SumOfHIV_infected
# 5573                 0.0
# 6203                 6.0
# 6834                 5.0
# 7469                 9.0
# 8111                 6.0
# 8753                 9.0
# 9397                13.0
# 10041               11.0
# 10682               12.0
# 11326               18.0
# 11970               18.0
# 12614               10.0
# 13258               13.0
# 13903               15.0
# 14556               15.0
# 15214               10.0
# 15871               16.0
# 16535               22.0
# 17200               15.0
# 17866                6.0
# 18496               13.0
# 19212               23.0
# 19950                1.0
# 20673               10.0
# 21185                6.0
# 22072               15.0
# 22908                4.0
# 23667                8.0
# 29826                6.0
# 29827               10.0
# 29828               11.0
# 29829               10.0
# 29830                8.0
# 29831                7.0
# 29832                7.0
# 29833                7.0

# %%
UD = UD[['Date' , 'SumOfHIV_infected']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-9e0369d1bb76> in <module>
# ----> 1 UD = UD[['Date' , 'SumOfHIV_infected']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ...

# %%
UD
# Out:
#        SumOfHIV_infected
# 5573                 0.0
# 6203                 6.0
# 6834                 5.0
# 7469                 9.0
# 8111                 6.0
# 8753                 9.0
# 9397                13.0
# 10041               11.0
# 10682               12.0
# 11326               18.0
# 11970               18.0
# 12614               10.0
# 13258               13.0
# 13903               15.0
# 14556               15.0
# 15214               10.0
# 15871               16.0
# 16535               22.0
# 17200               15.0
# 17866                6.0
# 18496               13.0
# 19212               23.0
# 19950                1.0
# 20673               10.0
# 21185                6.0
# 22072               15.0
# 22908                4.0
# 23667                8.0
# 29826                6.0
# 29827               10.0
# 29828               11.0
# 29829               10.0
# 29830                8.0
# 29831                7.0
# 29832                7.0
# 29833                7.0

# %%
UD['SumOfHIV_infected'] = UD['SumOfHIV_infected'].astype(int)

# %%
UD
# Out:
#        SumOfHIV_infected
# 5573                   0
# 6203                   6
# 6834                   5
# 7469                   9
# 8111                   6
# 8753                   9
# 9397                  13
# 10041                 11
# 10682                 12
# 11326                 18
# 11970                 18
# 12614                 10
# 13258                 13
# 13903                 15
# 14556                 15
# 15214                 10
# 15871                 16
# 16535                 22
# 17200                 15
# 17866                  6
# 18496                 13
# 19212                 23
# 19950                  1
# 20673                 10
# 21185                  6
# 22072                 15
# 22908                  4
# 23667                  8
# 29826                  6
# 29827                 10
# 29828                 11
# 29829                 10
# 29830                  8
# 29831                  7
# 29832                  7
# 29833                  7

# %%
rolling_mean = UD.rolling(window = 12).mean()
rolling_std = UD.rolling(window = 12).std()
plt.plot(UD, color = 'blue', label = 'Original')
plt.plot(rolling_mean, color = 'red', label = 'Rolling Mean')
plt.plot(rolling_std, color = 'black', label = 'Rolling Std')
plt.legend(loc = 'best')
plt.title('Rolling Mean & Rolling Standard Deviation')
plt.show()

# %%
plt.xlabel('Date')
plt.ylabel('Sum of HIV infected')
plt.plot(UD)

# %%
UD = UD(parse_dates = 'Date' , index_col = 'Date')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-4b8b2b4cac28> in <module>
# ----> 1 UD = UD(parse_dates = 'Date' , index_col = 'Date')
#
# TypeError: 'DataFrame' object is not callable

# %%
UD.parse_dates = 'Date'

# %%
UD.index_col = 'Date'

# %%
UD.head()
# Out:
#       SumOfHIV_infected
# 5573                  0
# 6203                  6
# 6834                  5
# 7469                  9
# 8111                  6

# %%
plt.xlabel('Date')
plt.ylabel('Sum of HIV infected')
plt.plot(UD)

# %%
rolling_mean = UD.rolling(window = 12).mean()
rolling_std = UD.rolling(window = 12).std()
plt.plot(UD, color = 'blue', label = 'Original')
plt.plot(rolling_mean, color = 'red', label = 'Rolling Mean')
plt.plot(rolling_std, color = 'black', label = 'Rolling Std')
plt.legend(loc = 'best')
plt.title('Rolling Mean & Rolling Standard Deviation')
plt.show()

# %%
result = adfuller(UD['SumOfHIV_infected'])
print('ADF Statistic: {}'.format(result[0]))
print('p-value: {}'.format(result[1]))
print('Critical Values:')
for key, value in result[4].items():
    print('\t{}: {}'.format(key, value))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-905630302419> in <module>
# ----> 1 result = adfuller(UD['SumOfHIV_infected'])
#       2 print('ADF Statistic: {}'.format(result[0]))
#       3 print('p-value: {}'.format(result[1]))
#       4 print('Critical Values:')
#       5 for key, value in result[4].items():
#
# NameError: name 'adfuller' is not defined

# %%
import adfuller
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-67-af13dfe2c9e4> in <module>
# ----> 1 import adfuller
#
# ModuleNotFoundError: No module named 'adfuller'

# %%
from statsmodels.tsa.stattools import adfuller

# %%
ud_log = np.log(UD)
plt.plot(ud_log)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
UD['log'] = np.log(UD['SumOfHIV_infected'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
UD.head()
# Out:
#       SumOfHIV_infected       log
# 5573                  0      -inf
# 6203                  6  1.791759
# 6834                  5  1.609438
# 7469                  9  2.197225
# 8111                  6  1.791759

# %%
plt.plot(UD['Date'] , UD['log'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-d30327e0a6a7> in <module>
# ----> 1 plt.plot(UD['Date'] , UD['log'])
#
# ...

# %%
UD = UD.drop('SumOfHIV_infected' , axis = 1)

# %%
result = adfuller(UD['log'])
print('ADF Statistic: {}'.format(result[0]))
print('p-value: {}'.format(result[1]))
print('Critical Values:')
for key, value in result[4].items():
    print('\t{}: {}'.format(key, value))
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-74-7fd3f3ac0ca3> in <module>
# ----> 1 result = adfuller(UD['log'])
#       2 print('ADF Statistic: {}'.format(result[0]))
#       3 print('p-value: {}'.format(result[1]))
#       4 print('Critical Values:')
#       5 for key, value in result[4].items():
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     266         if not regresults:
#     267             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# --> 268                                        maxlag, autolag)
#     269         else:
#     270             icbest, bestlag, alres = _autolag(OLS, xdshort, fullRHS, startlag,
#
# ...

# %%
def get_stationarity(timeseries):
    
    # rolling statistics
    rolling_mean = timeseries.rolling(window=12).mean()
    rolling_std = timeseries.rolling(window=12).std()
    
    # rolling statistics plot
    original = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(rolling_mean, color='red', label='Rolling Mean')
    std = plt.plot(rolling_std, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    # Dickey–Fuller test:
    result = adfuller(timeseries['Passengers'])
    print('ADF Statistic: {}'.format(result[0]))
    print('p-value: {}'.format(result[1]))
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t{}: {}'.format(key, value))

# %%
rolling_mean = UD.rolling(window=12).mean()
df_log_minus_mean = UD - rolling_mean
df_log_minus_mean.dropna(inplace=True)
get_stationarity(df_log_minus_mean)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Passengers'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-ee9cda412a35> in <module>
# ...

# %%
model = ARIMA(UD, order=(5,1,0))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:214: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:214: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
model = ARIMA(endog=UD['log'] , order=(5,1,0) , exog= UD['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-0a03ab40a417> in <module>
# ...

# %%
UD.head()
# Out:
#            log
# 5573      -inf
# 6203  1.791759
# 6834  1.609438
# 7469  2.197225
# 8111  1.791759

# %%
UD.set_index(hiv['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-c04af1bbafa3> in <module>
# ----> 1 UD.set_index(hiv['Date'])
#
# ...

# %%
hiv.head()
# Out:
#    Year                      STATE            DISTRICT  SumOfHIV_Tested  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS              0.0
# 1  2008             Andhra Pradesh            ADILABAD            177.0
# 2  2008             Andhra Pradesh           ANANTAPUR            199.0
# 3  2008             Andhra Pradesh        BHADRACHALAM             89.0
# 4  2008             Andhra Pradesh            CUDDAPAH              0.0
#
#    SumOfHIV_infected  Quarter  Month
# 0                0.0        1      3
# 1               76.0        1      3
# 2               50.0        1      3
# 3                7.0        1      3
# 4                0.0        1      3

# %%
ger.head()
# Out:
#    Year                      STATE            DISTRICT  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1  2008             Andhra Pradesh            ADILABAD
# 2  2008             Andhra Pradesh           ANANTAPUR
# 3  2008             Andhra Pradesh        BHADRACHALAM
# 4  2008             Andhra Pradesh            CUDDAPAH
#
#    65 & above yrs NSP(NewAll207+) Male  65 & above yrs NSP(NewAll207+) Female  \
# 0                                  2.0                                    2.0
# 1                                 24.0                                    5.0
# 2                                 53.0                                    5.0
# 3                                  5.0                                    4.0
# 4                                 33.0                                    3.0
#
#    Total Geriatric  Quarter
# 0              4.0        1
# 1             29.0        1
# 2             58.0        1
# 3              9.0        1
# ...

# %%
ped.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-9ba5750ec69d> in <module>
# ----> 1 ped.head()
#
# NameError: name 'ped' is not defined

# %%
HIV = pd.read_csv('HIV.csv')

# %%
HIV.head()
# Out:
#    Year                      STATE            DISTRICT  SumOfHIV_Tested  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS              0.0
# 1  2008             Andhra Pradesh            ADILABAD            177.0
# 2  2008             Andhra Pradesh           ANANTAPUR            199.0
# 3  2008             Andhra Pradesh        BHADRACHALAM             89.0
# 4  2008             Andhra Pradesh            CUDDAPAH              0.0
#
#    SumOfHIV_infected  Quarter  Month        Date
# 0                0.0        1      3  2008-03-01
# 1               76.0        1      3  2008-03-01
# 2               50.0        1      3  2008-03-01
# 3                7.0        1      3  2008-03-01
# 4                0.0        1      3  2008-03-01

# %%
HIV.tail()
# Out:
#        Year        STATE        DISTRICT  SumOfHIV_Tested  SumOfHIV_infected  \
# 29829  2017  West Bengal  Uttar Dinajpur            466.0               10.0
# 29830  2018  West Bengal  Uttar Dinajpur            574.0                8.0
# 29831  2018  West Bengal  Uttar Dinajpur            559.0                7.0
# 29832  2018  West Bengal  Uttar Dinajpur            448.0                7.0
# 29833  2018  West Bengal  Uttar Dinajpur            370.0                7.0
#
#        Quarter  Month        Date
# 29829        4     12  2017-12-01
# 29830        1      3  2018-03-01
# 29831        2      6  2018-06-01
# 29832        3      9  2018-09-01
# 29833        4     12  2018-12-01

# %%
h = HIV.groupby('DISTRICT')

# %%
h = h.get_group('Uttar Dinajpur')

# %%
h.head()
# Out:
#       Year        STATE        DISTRICT  SumOfHIV_Tested  SumOfHIV_infected  \
# 5573  2010  West Bengal  Uttar Dinajpur              0.0                0.0
# 6203  2010  West Bengal  Uttar Dinajpur            111.0                6.0
# 6834  2010  West Bengal  Uttar Dinajpur            115.0                5.0
# 7469  2010  West Bengal  Uttar Dinajpur            200.0                9.0
# 8111  2011  West Bengal  Uttar Dinajpur            236.0                6.0
#
#       Quarter  Month        Date
# 5573        1      3  2010-03-01
# 6203        2      6  2010-06-01
# 6834        3      9  2010-09-01
# 7469        4     12  2010-12-01
# 8111        1      3  2011-03-01

# %%
UD.set_index(h['Date'])
# Out:
#                  log
# Date
# 2010-03-01      -inf
# 2010-06-01  1.791759
# 2010-09-01  1.609438
# 2010-12-01  2.197225
# 2011-03-01  1.791759
# 2011-06-01  2.197225
# 2011-09-01  2.564949
# 2011-12-01  2.397895
# 2012-03-01  2.484907
# 2012-06-01  2.890372
# 2012-09-01  2.890372
# 2012-12-01  2.302585
# 2013-03-01  2.564949
# 2013-06-01  2.708050
# 2013-09-01  2.708050
# 2013-12-01  2.302585
# 2014-03-01  2.772589
# 2014-06-01  3.091042
# 2014-09-01  2.708050
# 2014-12-01  1.791759
# 2015-03-01  2.564949
# 2015-06-01  3.135494
# 2015-09-01  0.000000
# 2015-12-01  2.302585
# 2016-03-01  1.791759
# 2016-06-01  2.708050
# 2016-09-01  1.386294
# 2016-12-01  2.079442
# 2017-03-01  1.791759
# 2017-06-01  2.302585
# 2017-09-01  2.397895
# 2017-12-01  2.302585
# 2018-03-01  2.079442
# 2018-06-01  1.945910
# 2018-09-01  1.945910
# 2018-12-01  1.945910

# %%
model = ARIMA(UD , order= (5,1,0))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:214: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:214: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
model_fit = model.fit(disp=0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:503: RuntimeWarning: invalid value encountered in subtract
#   endog -= np.dot(exog, ols_params).squeeze()
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-97-8b2d947130bc> in <module>
# ----> 1 model_fit = model.fit(disp=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1198                                         method, transparams, solver,
#    1199                                         maxiter, full_output, disp,
# -> 1200                                         callback, start_ar_lags, **kwargs)
#    1201         normalized_cov_params = None  # TODO: fix this?
# ...

# %%
UD = UD.replace([np.inf, -np.inf], np.nan)

# %%
UD.dropna()
# Out:
#             log
# 6203   1.791759
# 6834   1.609438
# 7469   2.197225
# 8111   1.791759
# 8753   2.197225
# 9397   2.564949
# 10041  2.397895
# 10682  2.484907
# 11326  2.890372
# 11970  2.890372
# 12614  2.302585
# 13258  2.564949
# 13903  2.708050
# 14556  2.708050
# 15214  2.302585
# 15871  2.772589
# 16535  3.091042
# 17200  2.708050
# 17866  1.791759
# 18496  2.564949
# 19212  3.135494
# 19950  0.000000
# 20673  2.302585
# 21185  1.791759
# 22072  2.708050
# 22908  1.386294
# 23667  2.079442
# 29826  1.791759
# 29827  2.302585
# 29828  2.397895
# 29829  2.302585
# 29830  2.079442
# 29831  1.945910
# 29832  1.945910
# 29833  1.945910

# %%
UD = UD.set_index(h['Date'])

# %%
UD.head()
# Out:
#                  log
# Date
# 2010-03-01       NaN
# 2010-06-01  1.791759
# 2010-09-01  1.609438
# 2010-12-01  2.197225
# 2011-03-01  1.791759

# %%
UD = UD.dropna()

# %%
UD.head()
# Out:
#                  log
# Date
# 2010-06-01  1.791759
# 2010-09-01  1.609438
# 2010-12-01  2.197225
# 2011-03-01  1.791759
# 2011-06-01  2.197225

# %%
model = ARIMA(UD , order= (5,1,0))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)

# %%
model_fit = model.fit(disp=0)

# %%
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                  D.log   No. Observations:                   34
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                 -28.366
# Method:                       css-mle   S.D. of innovations              0.547
# Date:                Thu, 08 Oct 2020   AIC                             70.731
# Time:                        16:12:26   BIC                             81.416
# Sample:                    09-01-2010   HQIC                            74.375
#                          - 12-01-2018
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0048      0.037      0.128      0.898      -0.068       0.078
# ar.L1.D.log    -0.9347      0.170     -5.511      0.000      -1.267      -0.602
# ar.L2.D.log    -0.6043      0.237     -2.555      0.011      -1.068      -0.141
# ...

# %%
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()

# %%
residuals.plot(kind='kde')

# %%
print(residuals.describe())
# Out:
#                0
# count  34.000000
# mean   -0.000633
# std     0.557498
# min    -2.384200
# 25%    -0.178141
# 50%     0.064096
# 75%     0.269836
# max     0.770947

# %%
UD.shape
# Out:
# (35, 1)

# %%
train = UD[:30]

# %%
test = UD[30:]

# %%
train
# Out:
#                  log
# Date
# 2010-06-01  1.791759
# 2010-09-01  1.609438
# 2010-12-01  2.197225
# 2011-03-01  1.791759
# 2011-06-01  2.197225
# 2011-09-01  2.564949
# 2011-12-01  2.397895
# 2012-03-01  2.484907
# 2012-06-01  2.890372
# 2012-09-01  2.890372
# 2012-12-01  2.302585
# 2013-03-01  2.564949
# 2013-06-01  2.708050
# 2013-09-01  2.708050
# 2013-12-01  2.302585
# 2014-03-01  2.772589
# 2014-06-01  3.091042
# 2014-09-01  2.708050
# 2014-12-01  1.791759
# 2015-03-01  2.564949
# 2015-06-01  3.135494
# 2015-09-01  0.000000
# 2015-12-01  2.302585
# 2016-03-01  1.791759
# 2016-06-01  2.708050
# 2016-09-01  1.386294
# 2016-12-01  2.079442
# 2017-03-01  1.791759
# 2017-06-01  2.302585
# 2017-09-01  2.397895

# %%
test
# Out:
#                  log
# Date
# 2017-12-01  2.302585
# 2018-03-01  2.079442
# 2018-06-01  1.945910
# 2018-09-01  1.945910
# 2018-12-01  1.945910

# %%
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-2ebd87e97b44> in <module>
#       2 predictions = list()
#       3 for t in range(len(test)):
# ----> 4     model = ARIMA(history, order=(5,1,0))
#       5     model_fit = model.fit(disp=0)
#       6     output = model_fit.forecast()
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#    1038         else:
#    1039             mod = super(ARIMA, cls).__new__(cls)
# -> 1040             mod.__init__(endog, order, exog, dates, freq, missing)
#    1041             return mod
#    1042
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1057             #  in the predict method
#    1058             raise ValueError("d > 2 is not supported")
# ...

# %%
UD['log'] = UD['log'].astype(float)

# %%
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-2ebd87e97b44> in <module>
#       2 predictions = list()
#       3 for t in range(len(test)):
# ----> 4     model = ARIMA(history, order=(5,1,0))
#       5     model_fit = model.fit(disp=0)
#       6     output = model_fit.forecast()
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#    1038         else:
#    1039             mod = super(ARIMA, cls).__new__(cls)
# -> 1040             mod.__init__(endog, order, exog, dates, freq, missing)
#    1041             return mod
#    1042
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1057             #  in the predict method
#    1058             raise ValueError("d > 2 is not supported")
# ...

# %%
UD.head()
# Out:
#                  log
# Date
# 2010-06-01  1.791759
# 2010-09-01  1.609438
# 2010-12-01  2.197225
# 2011-03-01  1.791759
# 2011-06-01  2.197225

# %%
model = ARIMA(history, order=(5,1,0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-cd7dd18f6d07> in <module>
# ----> 1 model = ARIMA(history, order=(5,1,0))
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#    1038         else:
#    1039             mod = super(ARIMA, cls).__new__(cls)
# -> 1040             mod.__init__(endog, order, exog, dates, freq, missing)
#    1041             return mod
#    1042
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1057             #  in the predict method
#    1058             raise ValueError("d > 2 is not supported")
# -> 1059         super(ARIMA, self).__init__(endog, (p, q), exog, dates, freq, missing)
#    1060         self.k_diff = d
# ...

# %%
HIV.head()
# Out:
#    Year                      STATE            DISTRICT  SumOfHIV_Tested  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS              0.0
# 1  2008             Andhra Pradesh            ADILABAD            177.0
# 2  2008             Andhra Pradesh           ANANTAPUR            199.0
# 3  2008             Andhra Pradesh        BHADRACHALAM             89.0
# 4  2008             Andhra Pradesh            CUDDAPAH              0.0
#
#    SumOfHIV_infected  Quarter  Month        Date
# 0                0.0        1      3  2008-03-01
# 1               76.0        1      3  2008-03-01
# 2               50.0        1      3  2008-03-01
# 3                7.0        1      3  2008-03-01
# 4                0.0        1      3  2008-03-01

# %%
UD['log'] = HIV['SumOfHIV_infected']

# %%
model = ARIMA(history, order=(5,1,0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-cd7dd18f6d07> in <module>
# ----> 1 model = ARIMA(history, order=(5,1,0))
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#    1038         else:
#    1039             mod = super(ARIMA, cls).__new__(cls)
# -> 1040             mod.__init__(endog, order, exog, dates, freq, missing)
#    1041             return mod
#    1042
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1057             #  in the predict method
#    1058             raise ValueError("d > 2 is not supported")
# -> 1059         super(ARIMA, self).__init__(endog, (p, q), exog, dates, freq, missing)
#    1060         self.k_diff = d
# ...

# %%
UD['hiv'] = HIV['SumOfHIV_infected']

# %%
UD.head()
# Out:
#             log  hiv
# Date
# 2010-06-01  NaN  NaN
# 2010-09-01  NaN  NaN
# 2010-12-01  NaN  NaN
# 2011-03-01  NaN  NaN
# 2011-06-01  NaN  NaN

# %%
UD()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-60fd557ee9ce> in <module>
# ----> 1 UD()
#
# TypeError: 'DataFrame' object is not callable

# %%
UD
# Out:
#             log  hiv
# Date
# 2010-06-01  NaN  NaN
# 2010-09-01  NaN  NaN
# 2010-12-01  NaN  NaN
# 2011-03-01  NaN  NaN
# 2011-06-01  NaN  NaN
# 2011-09-01  NaN  NaN
# 2011-12-01  NaN  NaN
# 2012-03-01  NaN  NaN
# 2012-06-01  NaN  NaN
# 2012-09-01  NaN  NaN
# 2012-12-01  NaN  NaN
# 2013-03-01  NaN  NaN
# 2013-06-01  NaN  NaN
# 2013-09-01  NaN  NaN
# 2013-12-01  NaN  NaN
# 2014-03-01  NaN  NaN
# 2014-06-01  NaN  NaN
# 2014-09-01  NaN  NaN
# 2014-12-01  NaN  NaN
# 2015-03-01  NaN  NaN
# 2015-06-01  NaN  NaN
# 2015-09-01  NaN  NaN
# 2015-12-01  NaN  NaN
# 2016-03-01  NaN  NaN
# 2016-06-01  NaN  NaN
# 2016-09-01  NaN  NaN
# 2016-12-01  NaN  NaN
# 2017-03-01  NaN  NaN
# 2017-06-01  NaN  NaN
# 2017-09-01  NaN  NaN
# 2017-12-01  NaN  NaN
# 2018-03-01  NaN  NaN
# 2018-06-01  NaN  NaN
# 2018-09-01  NaN  NaN
# 2018-12-01  NaN  NaN

# %%
HIV.head()
# Out:
#    Year                      STATE            DISTRICT  SumOfHIV_Tested  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS              0.0
# 1  2008             Andhra Pradesh            ADILABAD            177.0
# 2  2008             Andhra Pradesh           ANANTAPUR            199.0
# 3  2008             Andhra Pradesh        BHADRACHALAM             89.0
# 4  2008             Andhra Pradesh            CUDDAPAH              0.0
#
#    SumOfHIV_infected  Quarter  Month        Date
# 0                0.0        1      3  2008-03-01
# 1               76.0        1      3  2008-03-01
# 2               50.0        1      3  2008-03-01
# 3                7.0        1      3  2008-03-01
# 4                0.0        1      3  2008-03-01

# %%
UD.drop(['log' , 'hiv'] , axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [2010-06-01, 2010-09-01, 2010-12-01, 2011-03-01, 2011-06-01, 2011-09-01, 2011-12-01, 2012-03-01, 2012-06-01, 2012-09-01, 2012-12-01, 2013-03-01, 2013-06-01, 2013-09-01, 2013-12-01, 2014-03-01, 2014-06-01, 2014-09-01, 2014-12-01, 2015-03-01, 2015-06-01, 2015-09-01, 2015-12-01, 2016-03-01, 2016-06-01, 2016-09-01, 2016-12-01, 2017-03-01, 2017-06-01, 2017-09-01, 2017-12-01, 2018-03-01, 2018-06-01, 2018-09-01, 2018-12-01]

# %%
UD['sum'] = HIV['SumOfHIV_infected']

# %%
UD.head()
# Out:
#             log  hiv  sum
# Date
# 2010-06-01  NaN  NaN  NaN
# 2010-09-01  NaN  NaN  NaN
# 2010-12-01  NaN  NaN  NaN
# 2011-03-01  NaN  NaN  NaN
# 2011-06-01  NaN  NaN  NaN

# %%
UD.shape
# Out:
# (35, 3)

# %%
h.shape
# Out:
# (36, 8)

# %%
h.head()
# Out:
#       Year        STATE        DISTRICT  SumOfHIV_Tested  SumOfHIV_infected  \
# 5573  2010  West Bengal  Uttar Dinajpur              0.0                0.0
# 6203  2010  West Bengal  Uttar Dinajpur            111.0                6.0
# 6834  2010  West Bengal  Uttar Dinajpur            115.0                5.0
# 7469  2010  West Bengal  Uttar Dinajpur            200.0                9.0
# 8111  2011  West Bengal  Uttar Dinajpur            236.0                6.0
#
#       Quarter  Month        Date
# 5573        1      3  2010-03-01
# 6203        2      6  2010-06-01
# 6834        3      9  2010-09-01
# 7469        4     12  2010-12-01
# 8111        1      3  2011-03-01

# %%
UD = h['SumOfHIV_infected']

# %%
UD.set_index(h['Date'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-161-ffda46fbf4e1> in <module>
# ----> 1 UD.set_index(h['Date'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'set_index'

# %%
UD = pd.DataFrame(h)

# %%
UD = UD.drop(['Year' , 'STATE' , 'DISTRICT' , 'SumOfHIV_Tested' , 'Quarter' , 'Month'] ,  axis = 1)

# %%
UD.set_index('Date')
# Out:
#             SumOfHIV_infected
# Date
# 2010-03-01                0.0
# 2010-06-01                6.0
# 2010-09-01                5.0
# 2010-12-01                9.0
# 2011-03-01                6.0
# 2011-06-01                9.0
# 2011-09-01               13.0
# 2011-12-01               11.0
# 2012-03-01               12.0
# 2012-06-01               18.0
# 2012-09-01               18.0
# 2012-12-01               10.0
# 2013-03-01               13.0
# 2013-06-01               15.0
# 2013-09-01               15.0
# 2013-12-01               10.0
# 2014-03-01               16.0
# 2014-06-01               22.0
# 2014-09-01               15.0
# 2014-12-01                6.0
# 2015-03-01               13.0
# 2015-06-01               23.0
# 2015-09-01                1.0
# 2015-12-01               10.0
# 2016-03-01                6.0
# 2016-06-01               15.0
# 2016-09-01                4.0
# 2016-12-01                8.0
# 2017-03-01                6.0
# 2017-06-01               10.0
# ...

# %%
UD['SumOfHIV_infected'] = UD['SumOfHIV_infected'].astype(int)

# %%
UD.head()
# Out:
#             SumOfHIV_infected  SumOfHIV_Tested
# Date
# 2010-03-01                  0                0
# 2010-06-01                  6                6
# 2010-09-01                  5                5
# 2010-12-01                  9                9
# 2011-03-01                  6                6

# %%
UD = UD.set_index('Date')

# %%
UD.head()
# Out:
#             SumOfHIV_infected  SumOfHIV_Tested
# Date
# 2010-03-01                  0                0
# 2010-06-01                  6                6
# 2010-09-01                  5                5
# 2010-12-01                  9                9
# 2011-03-01                  6                6

# %%
UD = UD.drop('SumOfHIV_Tested' , axis = 1)

# %%
UD.head()
# Out:
#             SumOfHIV_infected
# Date
# 2010-03-01                  0
# 2010-06-01                  6
# 2010-09-01                  5
# 2010-12-01                  9
# 2011-03-01                  6

# %%
train = UD[:30]

# %%
test = UD[30:]

# %%
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-182-2ebd87e97b44> in <module>
#       2 predictions = list()
#       3 for t in range(len(test)):
# ----> 4     model = ARIMA(history, order=(5,1,0))
#       5     model_fit = model.fit(disp=0)
#       6     output = model_fit.forecast()
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#    1038         else:
#    1039             mod = super(ARIMA, cls).__new__(cls)
# -> 1040             mod.__init__(endog, order, exog, dates, freq, missing)
#    1041             return mod
#    1042
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1057             #  in the predict method
#    1058             raise ValueError("d > 2 is not supported")
# ...

# %%
    model = ARIMA(UD, order=(5,1,0))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)

# %%
predictions = list()
for t in range(len(test)):
    model = ARIMA(UD, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
UD = UD.iloc[1:]

# %%
predictions = list()
for t in range(len(test)):
    model = ARIMA(UD, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
UD.shape
# Out:
# (34, 1)

# %%
model = ARIMA(UD, order=(5,1,0))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)

# %%
model_fit = model.fit(disp=0)

# %%
output = model_fit.forecast()

# %%
output
# Out:
# (array([6.53181549]), array([4.15985856]), array([[-1.62135747, 14.68498845]]))

# %%
predictions = list()
for t in range(len(test)):
    model = ARIMA(UD, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
output[0]
# Out:
# array([6.53181549])

# %%
predictions = list()
for t in range(len(test)):
    model = ARIMA(UD, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
forecast = model_fit.forecast()[0]

# %%
forecast
# Out:
# array([6.53181549])

# %%
len(output)
# Out:
# 3

# %%
UD
# Out:
#             SumOfHIV_infected
# Date
# 2010-09-01                  5
# 2010-12-01                  9
# 2011-03-01                  6
# 2011-06-01                  9
# 2011-09-01                 13
# 2011-12-01                 11
# 2012-03-01                 12
# 2012-06-01                 18
# 2012-09-01                 18
# 2012-12-01                 10
# 2013-03-01                 13
# 2013-06-01                 15
# 2013-09-01                 15
# 2013-12-01                 10
# 2014-03-01                 16
# 2014-06-01                 22
# 2014-09-01                 15
# 2014-12-01                  6
# 2015-03-01                 13
# 2015-06-01                 23
# 2015-09-01                  1
# 2015-12-01                 10
# 2016-03-01                  6
# 2016-06-01                 15
# 2016-09-01                  4
# 2016-12-01                  8
# 2017-03-01                  6
# 2017-06-01                 10
# 2017-09-01                 11
# 2017-12-01                 10
# ...

# %%
UD.to_csv(r'Downloads/UD.csv')
