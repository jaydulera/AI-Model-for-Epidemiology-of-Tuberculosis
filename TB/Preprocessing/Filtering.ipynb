# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten

# %%
train = pd.read_csv('TemporaryTrain.csv')

# %%
test = pd.read_csv('Test.csv')

# %%
train.drop('Unnamed: 0' , axis = 1 , inplace = True)

# %%
train_state = pd.get_dummies(train['State_x'])

# %%
train_district = pd.get_dummies(train['District'])

# %%
yes_train = pd.concat([train_state , train_district , train] , axis = 1)

# %%
test
# Out:
#                State   District  ... Relapse Total  NSN Total
# 0     Andhra Pradesh  Anantapur  ...     55.514507  215.95978
# 1     Andhra Pradesh  Anantapur  ...     60.780483  230.09021
# 2     Andhra Pradesh  Anantapur  ...     53.123070  247.26550
# 3     Andhra Pradesh  Anantapur  ...     42.505463  352.44174
# 4     Andhra Pradesh  Anantapur  ...     49.609444  293.21860
# ...              ...        ...  ...           ...        ...
# 1627  Madhya Pradesh     Ujjain  ...    104.072950  263.89417
# 1628  Madhya Pradesh     Ujjain  ...    100.013680  283.90305
# 1629  Madhya Pradesh     Ujjain  ...    120.911580  287.17892
# 1630  Madhya Pradesh     Ujjain  ...    119.618480  292.54320
# 1631  Madhya Pradesh     Ujjain  ...    106.345510  319.68262
#
# [1632 rows x 9 columns]

# %%
test_state = pd.get_dummies(test['State'])

# %%
test_district = pd.get_dummies(test['District'])

# %%
yes_test = pd.concat([test_state , test_district , test] , axis = 1)

# %%
yes_test
# Out:
#       Andhra Pradesh  Assam  Bihar  ...  NSP Total  Relapse Total  NSN Total
# 0                  1      0      0  ...  692.19366      55.514507  215.95978
# 1                  1      0      0  ...  755.53880      60.780483  230.09021
# 2                  1      0      0  ...  681.75270      53.123070  247.26550
# 3                  1      0      0  ...  610.22437      42.505463  352.44174
# 4                  1      0      0  ...  704.64570      49.609444  293.21860
# ...              ...    ...    ...  ...        ...            ...        ...
# 1627               0      0      0  ...  256.25510     104.072950  263.89417
# 1628               0      0      0  ...  191.21191     100.013680  283.90305
# 1629               0      0      0  ...  211.58060     120.911580  287.17892
# 1630               0      0      0  ...  250.24135     119.618480  292.54320
# 1631               0      0      0  ...  267.43490     106.345510  319.68262
#
# [1632 rows x 87 columns]

# %%
yes_train
# Out:
#       ANDHRAPRADESH  ASSAM  ...  SumOfHIV_Tested  SumOfHIV_infected
# 0                 1      0  ...              199                 50
# 1                 1      0  ...              170                 68
# 2                 1      0  ...              263                 73
# 3                 1      0  ...              369                 72
# 4                 1      0  ...              605                109
# ...             ...    ...  ...              ...                ...
# 2899              0      0  ...              341                  3
# 2900              0      0  ...              388                  2
# 2901              0      0  ...              496                  6
# 2902              0      0  ...              444                  6
# 2903              0      0  ...              416                 18
#
# [2904 rows x 111 columns]

# %%
correct_train = yes_train.loc[: , 'ANDHRAPRADESH' : 'NEP Female']

# %%
correct_train.drop(['NEP Male' , 'NEP Female'] , axis = 1 , inplace = True)

# %%
correct_train['Relapse Total'] = correct_train['Relapse Male'] + correct_train['Relapse Female']

# %%
correct_train.drop(['NSP Male/ NewMicConfMale'  , 'NSP Female/ NewMicConf Female' , 'Relapse Male' , 'Relapse Female' , 'NSN Male/NewClinDiag Male' , 'NSN Female/NewClinDiag Female'] , axis = 1 , inplace = True)

# %%
col = correct_train.columns

# %%
ekdum_final = correct_train[['ANDHRAPRADESH', 'ASSAM', 'BIHAR', 'CHANDIGARH', 'CHHATTISGARH', 'GOA',
       'GUJARAT', 'HARYANA', 'HIMACHALPRADESH', 'JHARKHAND', 'KARNATAKA',
       'KERALA', 'MADHYAPRADESH', 'ALAPPUZHA', 'ANANTAPUR', 'BHARUCH',
       'BHIWANI', 'BHOPAL', 'BIDAR', 'BONGAIGAON', 'CHANDIGARH', 'CHHATARPUR',
       'CHITRADURGA', 'CHITTOOR', 'DAKSHINAKANNADA', 'DARRANG', 'DAVANAGERE',
       'DHANBAD', 'DHEMAJI', 'DIBRUGARH', 'DURG', 'EASTGODAVARI', 'ERNAKULAM',
       'GANDHINAGAR', 'GOLAGHAT', 'GUNTUR', 'GWALIOR', 'HASSAN', 'INDORE',
       'JABALPUR', 'JAMNAGAR', 'JORHAT', 'KAMRUP', 'KARIMGANJ', 'KOLAR',
       'KOLLAM', 'KORBA', 'KOTTAYAM', 'KOZHIKODE', 'KULLU', 'KURNOOL',
       'LAKHIMPUR', 'MANDYA', 'NELLORE', 'NORTHGOA', 'PALAKKAD', 'PANCHKULA',
       'PRAKASAM', 'RAICHUR', 'RAJKOT', 'RANCHI', 'RATLAM', 'SAGAR',
       'SAMASTIPUR', 'SATNA', 'SIRMAUR', 'SOLAN', 'SONITPUR', 'SOUTHGOA',
       'SURAT', 'THIRUVANANTHAPURAM', 'UJJAIN', 'UNA', 'VADODARA', 'VALSAD',
       'VISAKHAPATNAM', 'VIZIANAGARAM', 'WAYANAD', 'YAMUNANAGAR', 'year', 'quarter', 'rainfall', 'relative_humidity',
       'average_temperature', 'NSP Total/ NewMicConf Total','Relapse Total' , 'NSN Total']]

# %%
ekdum_final.columns
# Out:
# Index(['ANDHRAPRADESH', 'ASSAM', 'BIHAR', 'CHANDIGARH', 'CHANDIGARH',
#        'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHALPRADESH',
#        'JHARKHAND', 'KARNATAKA', 'KERALA', 'MADHYAPRADESH', 'ALAPPUZHA',
#        'ANANTAPUR', 'BHARUCH', 'BHIWANI', 'BHOPAL', 'BIDAR', 'BONGAIGAON',
#        'CHANDIGARH', 'CHANDIGARH', 'CHHATARPUR', 'CHITRADURGA', 'CHITTOOR',
#        'DAKSHINAKANNADA', 'DARRANG', 'DAVANAGERE', 'DHANBAD', 'DHEMAJI',
#        'DIBRUGARH', 'DURG', 'EASTGODAVARI', 'ERNAKULAM', 'GANDHINAGAR',
#        'GOLAGHAT', 'GUNTUR', 'GWALIOR', 'HASSAN', 'INDORE', 'JABALPUR',
#        'JAMNAGAR', 'JORHAT', 'KAMRUP', 'KARIMGANJ', 'KOLAR', 'KOLLAM', 'KORBA',
#        'KOTTAYAM', 'KOZHIKODE', 'KULLU', 'KURNOOL', 'LAKHIMPUR', 'MANDYA',
#        'NELLORE', 'NORTHGOA', 'PALAKKAD', 'PANCHKULA', 'PRAKASAM', 'RAICHUR',
#        'RAJKOT', 'RANCHI', 'RATLAM', 'SAGAR', 'SAMASTIPUR', 'SATNA', 'SIRMAUR',
#        'SOLAN', 'SONITPUR', 'SOUTHGOA', 'SURAT', 'THIRUVANANTHAPURAM',
# ...

# %%
col = yes_test.columns

# %%
yes_test[['Andhra Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh', 'Goa',
       'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jharkhand', 'Karnataka',
       'Kerala', 'Madhya Pradesh', 'Alappuzha', 'Anantapur', 'Bharuch',
       'Bhiwani', 'Bhopal', 'Bidar', 'Bongaigaon', 'Chandigarh', 'Chhatarpur',
       'Chitradurga', 'Dakshina Kannada', 'Darrang', 'Davanagere', 'Dhanbad',
       'Dhemaji', 'Dibrugarh', 'Durg', 'East_Godavari', 'Ernakulam',
       'Gandhinagar', 'Golaghat', 'Guntur', 'Gwalior', 'Hassan', 'Indore',
       'Jabalpur', 'Jamnagar', 'Jorhat', 'Kamrup', 'Karimganj', 'Kolar',
       'Kollam', 'Korba', 'Kottayam', 'Kozhikode', 'Kullu', 'Kurnool',
       'Lakhimpur', 'Mandya', 'Nellore', 'North_Goa', 'Palakkad', 'Panchkula',
       'Prakasam', 'Raichur', 'Rajkot', 'Ranchi', 'Ratlam', 'Sagar',
       'Samastipur', 'Satna', 'Sirmaur', 'Solan', 'Sonitpur', 'South_Goa',
       'Surat', 'Thiruvananthapuram', 'Ujjain', 'Una', 'Vadodara', 'Valsad',
       'Visakhapatnam', 'Vizianagaram', 'Wayanad', 'Yamunanagar', 'Year', 'Rainfall', 'Relative Humidity',
       'Average Temperature', 'NSP Total', 'Relapse Total', 'NSN Total']]
# Out:
#       Andhra Pradesh  Assam  Bihar  ...  NSP Total  Relapse Total  NSN Total
# 0                  1      0      0  ...  692.19366      55.514507  215.95978
# 1                  1      0      0  ...  755.53880      60.780483  230.09021
# 2                  1      0      0  ...  681.75270      53.123070  247.26550
# 3                  1      0      0  ...  610.22437      42.505463  352.44174
# 4                  1      0      0  ...  704.64570      49.609444  293.21860
# ...              ...    ...    ...  ...        ...            ...        ...
# 1627               0      0      0  ...  256.25510     104.072950  263.89417
# 1628               0      0      0  ...  191.21191     100.013680  283.90305
# 1629               0      0      0  ...  211.58060     120.911580  287.17892
# 1630               0      0      0  ...  250.24135     119.618480  292.54320
# 1631               0      0      0  ...  267.43490     106.345510  319.68262
#
# [1632 rows x 87 columns]
