# %%
import pandas as pd

# %%
hiv = pd.read_csv('HIV.csv')

# %%
hiv.head()
# Out:
#    Unnamed: 0  Year                      STATE            DISTRICT  \
# 0           0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1           1  2008             Andhra Pradesh            ADILABAD
# 2           2  2008             Andhra Pradesh           ANANTAPUR
# 3           3  2008             Andhra Pradesh        BHADRACHALAM
# 4           4  2008             Andhra Pradesh            CUDDAPAH
#
#    SumOfHIV_Tested  SumOfHIV_infected  Quarter  Month        Date  Total
# 0              0.0                0.0        1      3  2008-03-01    136
# 1            177.0               76.0        1      3  2008-03-01    640
# 2            199.0               50.0        1      3  2008-03-01   1339
# 3             89.0                7.0        1      3  2008-03-01    342
# 4              0.0                0.0        1      3  2008-03-01    936

# %%
ped = pd.read_csv('Pediatric.csv')

# %%
ped.head()
# Out:
#    Unnamed: 0  Year                      STATE            DISTRICT  \
# 0           0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1           1  2008             Andhra Pradesh            ADILABAD
# 2           2  2008             Andhra Pradesh           ANANTAPUR
# 3           3  2008             Andhra Pradesh        BHADRACHALAM
# 4           4  2008             Andhra Pradesh            CUDDAPAH
#
#    0-14 yrs NSP(NewAll207+) Male  0-14 yrs NSP(NewAll207+) Female  \
# 0                            0.0                              2.0
# 1                            3.0                              4.0
# 2                            2.0                              3.0
# 3                            0.0                              3.0
# 4                            0.0                              2.0
#
#    Total Pediatric  Quarter  Total
# 0              2.0        1    136
# 1              7.0        1    640
# 2              5.0        1   1339
# ...

# %%
ped['Date'] = hiv['Date']

# %%
ped.head()
# Out:
#    Unnamed: 0  Year                      STATE            DISTRICT  \
# 0           0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1           1  2008             Andhra Pradesh            ADILABAD
# 2           2  2008             Andhra Pradesh           ANANTAPUR
# 3           3  2008             Andhra Pradesh        BHADRACHALAM
# 4           4  2008             Andhra Pradesh            CUDDAPAH
#
#    0-14 yrs NSP(NewAll207+) Male  0-14 yrs NSP(NewAll207+) Female  \
# 0                            0.0                              2.0
# 1                            3.0                              4.0
# 2                            2.0                              3.0
# 3                            0.0                              3.0
# 4                            0.0                              2.0
#
#    Total Pediatric  Quarter  Total        Date
# 0              2.0        1    136  2008-03-01
# 1              7.0        1    640  2008-03-01
# ...

# %%
ped.to_csv(r'Downloads/Pediatric1.csv' , index=False)

# %%
ger = pd.read_csv('Geriatric.csv')

# %%
ger.head()
# Out:
#    Unnamed: 0  Year                      STATE            DISTRICT  \
# 0           0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1           1  2008             Andhra Pradesh            ADILABAD
# 2           2  2008             Andhra Pradesh           ANANTAPUR
# 3           3  2008             Andhra Pradesh        BHADRACHALAM
# 4           4  2008             Andhra Pradesh            CUDDAPAH
#
#    65 & above yrs NSP(NewAll207+) Male  65 & above yrs NSP(NewAll207+) Female  \
# 0                                  2.0                                    2.0
# 1                                 24.0                                    5.0
# 2                                 53.0                                    5.0
# 3                                  5.0                                    4.0
# 4                                 33.0                                    3.0
#
#    Total Geriatric  Quarter  Total
# 0              4.0        1    136
# ...

# %%
ger['Date'] = hiv['Date']

# %%
ger.head()
# Out:
#    Unnamed: 0  Year                      STATE            DISTRICT  \
# 0           0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1           1  2008             Andhra Pradesh            ADILABAD
# 2           2  2008             Andhra Pradesh           ANANTAPUR
# 3           3  2008             Andhra Pradesh        BHADRACHALAM
# 4           4  2008             Andhra Pradesh            CUDDAPAH
#
#    65 & above yrs NSP(NewAll207+) Male  65 & above yrs NSP(NewAll207+) Female  \
# 0                                  2.0                                    2.0
# 1                                 24.0                                    5.0
# 2                                 53.0                                    5.0
# 3                                  5.0                                    4.0
# 4                                 33.0                                    3.0
#
#    Total Geriatric  Quarter  Total        Date
# ...

# %%
ger.to_csv(r'Downloads/Geriaric1.csv' , index=False)
