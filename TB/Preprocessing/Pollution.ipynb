# %%
import pandas as pd

# %%
df = pd.read_csv("pollution(2016-2018) (1).csv")

# %%
df.head()
# Out:
#               New_name_731  year  quarter       so2        no2       rspm
# 0  ANDHRAPRADESH_ANANTAPUR  2016        1  5.008285  13.197561  84.224375
# 1  ANDHRAPRADESH_ANANTAPUR  2017        1  5.008285  18.273546  77.288250
# 2  ANDHRAPRADESH_ANANTAPUR  2018        1  5.008285  19.034944  70.599844
# 3   ANDHRAPRADESH_CHITTOOR  2016        1  6.054546  26.461920  61.544956
# 4   ANDHRAPRADESH_CHITTOOR  2017        1  5.045455  43.936772  68.550073

# %%
df1 = pd.read_csv('pollution(1987-2018)_with_station-district_mapping (2).csv')

# %%
df1.head()
# Out:
#               New_name_731  year  quarter       so2        no2       rspm  spm
# 0  ANDHRAPRADESH_ANANTAPUR  2013        1  4.000000  10.750000  72.178571  NaN
# 1  ANDHRAPRADESH_ANANTAPUR  2013        2  4.000000  12.931034  86.620690  NaN
# 2  ANDHRAPRADESH_ANANTAPUR  2013        3  4.000000  13.928571  55.178571  NaN
# 3  ANDHRAPRADESH_ANANTAPUR  2013        4  4.000000  12.652174  64.478261  NaN
# 4  ANDHRAPRADESH_ANANTAPUR  2014        1  4.678571   9.892857  83.535714  NaN

# %%
dff = df1.drop('spm' , axis = 1)

# %%
df1['spm'].unique()
# Out:
# array([        nan,  60.5      ,  68.5      , ..., 120.7416667,
#        125.3854167, 170.8064516])

# %%
data = pd.concat([df , dff])

# %%
data.shape
# Out:
# (13983, 6)

# %%
sort = data.sort_values(by = ['New_name_731' , 'year' , 'quarter'])

# %%
sort['New_name_731'].unique()
# Out:
# array(['ANDHRAPRADESH_ANANTAPUR', 'ANDHRAPRADESH_CHITTOOR',
#        'ANDHRAPRADESH_EASTGODAVARI', 'ANDHRAPRADESH_GUNTUR',
#        'ANDHRAPRADESH_KADAPA', 'ANDHRAPRADESH_KRISHNA',
#        'ANDHRAPRADESH_KURNOOL', 'ANDHRAPRADESH_PRAKASAM',
#        'ANDHRAPRADESH_SRIKAKULAM',
#        'ANDHRAPRADESH_SRIPOTTISRIRAMULUNELLORE',
#        'ANDHRAPRADESH_VISAKHAPATNAM', 'ANDHRAPRADESH_VIZIANAGARAM',
#        'ANDHRAPRADESH_WESTGODAVARI', 'ARUNACHALPRADESH_PAPUMPARE',
#        'ASSAM_BONGAIGAON', 'ASSAM_CACHAR', 'ASSAM_DARRANG',
#        'ASSAM_DHEMAJI', 'ASSAM_DIBRUGARH', 'ASSAM_GOLAGHAT',
#        'ASSAM_HAILAKANDI', 'ASSAM_JORHAT', 'ASSAM_KAMRUP',
#        'ASSAM_KAMRUPMETROPOLITAN', 'ASSAM_KARBIANGLONG',
#        'ASSAM_KARIMGANJ', 'ASSAM_LAKHIMPUR', 'ASSAM_NAGAON',
#        'ASSAM_NALBARI', 'ASSAM_SIVASAGAR', 'ASSAM_SONITPUR',
#        'ASSAM_TINSUKIA', 'BIHAR_PATNA', 'BIHAR_SAMASTIPUR',
#        'CHANDIGARH_CHANDIGARH', 'CHHATTISGARH_BILASPUR',
# ...

# %%
name = sort.groupby('New_name_731')

# %%
name.get_group('ANDHRAPRADESH_ANANTAPUR')
# Out:
#                   New_name_731  year  quarter       so2        no2       rspm
# 0      ANDHRAPRADESH_ANANTAPUR  2013        1  4.000000  10.750000  72.178571
# 1      ANDHRAPRADESH_ANANTAPUR  2013        2  4.000000  12.931034  86.620690
# 2      ANDHRAPRADESH_ANANTAPUR  2013        3  4.000000  13.928571  55.178571
# 3      ANDHRAPRADESH_ANANTAPUR  2013        4  4.000000  12.652174  64.478261
# 4      ANDHRAPRADESH_ANANTAPUR  2014        1  4.678571   9.892857  83.535714
# 5      ANDHRAPRADESH_ANANTAPUR  2014        2  4.892857  10.107143  76.714286
# 6      ANDHRAPRADESH_ANANTAPUR  2014        3  5.000000  10.307692  71.038462
# 7      ANDHRAPRADESH_ANANTAPUR  2014        4  4.576923  11.000000  72.038462
# 8      ANDHRAPRADESH_ANANTAPUR  2015        1  5.296296  10.629630  87.481481
# 9      ANDHRAPRADESH_ANANTAPUR  2015        2  5.000000  10.703704  95.222222
# 10     ANDHRAPRADESH_ANANTAPUR  2015        3  4.925926  10.518519  85.777778
# ...

# %%
sort['year'].unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 1992, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2004, 1991, 1993, 1994, 1989, 1990, 2003, 1987, 1988],
#       dtype=int64)

# %%
data = pd.read_csv('data.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 15: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-21-71e55846462c> in <module>
# ----> 1 data = pd.read_csv('data.csv')
#
# ...
