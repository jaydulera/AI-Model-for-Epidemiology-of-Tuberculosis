# %%
import pandas as pd

# %%
df = pd.read_csv("pollution(1987-2018)_with_station-district_mapping (2).csv")

# %%
df.head()
# Out:
#               New_name_731  year  quarter       so2        no2       rspm  spm
# 0  ANDHRAPRADESH_ANANTAPUR  2013        1  4.000000  10.750000  72.178571  NaN
# 1  ANDHRAPRADESH_ANANTAPUR  2013        2  4.000000  12.931034  86.620690  NaN
# 2  ANDHRAPRADESH_ANANTAPUR  2013        3  4.000000  13.928571  55.178571  NaN
# 3  ANDHRAPRADESH_ANANTAPUR  2013        4  4.000000  12.652174  64.478261  NaN
# 4  ANDHRAPRADESH_ANANTAPUR  2014        1  4.678571   9.892857  83.535714  NaN

# %%
sort = df.sort_values(by = ['year' , 'quarter'])

# %%
sort = df[df['year'] > 2007]

# %% [raw]
# sort

# %%
sort = sort.sort_values(by = ['year' , 'quarter'])

# %%
sort.drop('spm' , axis = 1 , inplace = True)

# %%
sort['rspm'].unique()
# Out:
# array([ 31.2962963 , 101.75      ,  73.07407407, ...,  72.168481  ,
#         75.040086  , 126.6225409 ])

# %%
sort = sort.sort_values(by = ['New_name_731' , 'year' , 'quarter'])

# %%
abc = sort[sort['New_name_731'] == 'WESTBENGAL_MURSHIDABAD']
abc
# Out:
#                  New_name_731  year  quarter        so2        no2        rspm
# 10011  WESTBENGAL_MURSHIDABAD  2016        1   9.358305  62.349430  210.148603
# 10578  WESTBENGAL_MURSHIDABAD  2016        2   9.799654  66.254593  243.177739
# 11145  WESTBENGAL_MURSHIDABAD  2016        3  10.051806  68.899982  264.053412
# 11712  WESTBENGAL_MURSHIDABAD  2016        4   9.369038  63.475510  206.469821
# 10012  WESTBENGAL_MURSHIDABAD  2017        1   9.358305  62.349430  210.148603
# 10579  WESTBENGAL_MURSHIDABAD  2017        2   9.799654  66.254593  243.177739
# 11146  WESTBENGAL_MURSHIDABAD  2017        3  10.051806  68.899982  264.053412
# 11713  WESTBENGAL_MURSHIDABAD  2017        4   9.369038  63.475510  206.469821
# 10013  WESTBENGAL_MURSHIDABAD  2018        1   9.358305  62.349430  210.148603
# 10580  WESTBENGAL_MURSHIDABAD  2018        2   9.799654  66.254593  243.177739
# 11147  WESTBENGAL_MURSHIDABAD  2018        3  10.051806  68.899982  264.053412
# ...

# %%
abc.shape
# Out:
# (44, 6)

# %%
abc = pd.concat([abc[:8] , abc[4:]])

# %%
abc = pd.concat([abc[:12] , abc[8:12] , abc[12:]])

# %%
abc.to_csv(r'C:\Users\jayth\Downloads\TB\FINAL\Pollution/WESTBENGAL_KOLKATA.csv' , index = False)

# %%
abc['year'].iloc[12:16] = 2011
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
yr = abc['year']

# %%
import numpy as np

# %%
yr = np.array(yr)

# %%
yr = [2008, 2008, 2008, 2008, 2009, 2009, 2009, 2009, 2008, 2008, 2008,
       2008, 2009, 2009, 2009, 2009, 2010, 2010, 2010, 2010, 2011, 2011,
       2011, 2011, 2012, 2012, 2012, 2012, 2013, 2013, 2013, 2013, 2014,
       2014, 2014, 2014, 2015, 2015, 2015, 2015, 2016, 2016, 2016, 2016,
       2017, 2017, 2017, 2017, 2018, 2018, 2018, 2018]
# Out:
# array([2008, 2008, 2008, 2008, 2009, 2009, 2009, 2009, 2008, 2008, 2008,
#        2008, 2009, 2009, 2009, 2009, 2010, 2010, 2010, 2010, 2011, 2011,
#        2011, 2011, 2012, 2012, 2012, 2012, 2013, 2013, 2013, 2013, 2014,
#        2014, 2014, 2014, 2015, 2015, 2015, 2015, 2016, 2016, 2016, 2016,
#        2017, 2017, 2017, 2017, 2018, 2018, 2018, 2018], dtype=int64)

# %%
abc = abc[8:]

# %%
abc.shape
# Out:
# (44, 6)

# %%
abc = pd.concat([abc[:24] , abc[20:24] , abc[24:]])

# %%
abc['quarter'].iloc[2] = 3
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
abc = abc.fillna(method ='bfill')

# %%
abc[:31]
# Out:
#                   New_name_731  year  quarter        so2        no2       rspm
# 5469  MEGHALAYA_EASTKHASIHILLS  2008        1  22.000000  20.565517  75.891304
# 5470  MEGHALAYA_EASTKHASIHILLS  2008        2        NaN  17.066667  67.512195
# 5471  MEGHALAYA_EASTKHASIHILLS  2008        3        NaN  13.914286  69.358974
# 5472  MEGHALAYA_EASTKHASIHILLS  2008        4        NaN  19.452381  72.697674
# 5473  MEGHALAYA_EASTKHASIHILLS  2009        1        NaN  12.365385  81.589744
# 5474  MEGHALAYA_EASTKHASIHILLS  2009        2        NaN  11.782609  77.146341
# 5475  MEGHALAYA_EASTKHASIHILLS  2009        3        NaN  12.093333  75.057143
# 5476  MEGHALAYA_EASTKHASIHILLS  2009        4   6.000000  11.842857  76.571429
# 5477  MEGHALAYA_EASTKHASIHILLS  2010        1   2.344608  11.073039  86.033333
# 5478  MEGHALAYA_EASTKHASIHILLS  2010        2   2.000000   8.232540  80.730159
# 5479  MEGHALAYA_EASTKHASIHILLS  2010        3   2.358889  12.120741  81.200000
# ...

# %%
abc.quarter.iloc[31] = 4

# %%
abc[20:]
# Out:
#                New_name_731  year  quarter        so2        no2        rspm
# 8080   UTTARAKHAND_DEHRADUN  2013        1  23.412500  25.806579  133.400000
# 8081   UTTARAKHAND_DEHRADUN  2013        2  24.476923  26.678846  146.642925
# 8082   UTTARAKHAND_DEHRADUN  2013        3  22.341667  24.375595  122.695833
# 8083   UTTARAKHAND_DEHRADUN  2013        4  24.079969  27.695652  134.183230
# 8084   UTTARAKHAND_DEHRADUN  2015        1  25.888605  29.366071  155.073129
# 8085   UTTARAKHAND_DEHRADUN  2015        2  26.438545  30.311189  162.182692
# 8086   UTTARAKHAND_DEHRADUN  2015        3  25.865900  29.199234  139.839080
# 8087   UTTARAKHAND_DEHRADUN  2015        4  25.502646  28.417989  164.925926
# 9987   UTTARAKHAND_DEHRADUN  2016        1  27.357824  29.783981  230.904510
# 10554  UTTARAKHAND_DEHRADUN  2016        2  25.959856  29.027651  230.627360
# 11121  UTTARAKHAND_DEHRADUN  2016        3  26.899340  30.114744  269.607905
# ...

# %%
abc = pd.concat([abc[:31] , abc[30:31] , abc[31:]])

# %%
abc[20:24].year = 2013
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
abc
# Out:
#                     New_name_731  year  quarter        so2        no2  \
# 9415   WESTBENGAL_PURBAMEDINIPUR  2008        1  10.126000  50.968000
# 9416   WESTBENGAL_PURBAMEDINIPUR  2008        2   8.757692  48.626923
# 9417   WESTBENGAL_PURBAMEDINIPUR  2008        3   8.158000  46.180000
# 9418   WESTBENGAL_PURBAMEDINIPUR  2008        4   9.633929  53.846429
# 9419   WESTBENGAL_PURBAMEDINIPUR  2009        1   9.500000  66.408333
# 9420   WESTBENGAL_PURBAMEDINIPUR  2009        2  10.100000  70.400000
# 9421   WESTBENGAL_PURBAMEDINIPUR  2009        3   9.700000  68.300000
# 9422   WESTBENGAL_PURBAMEDINIPUR  2009        4   9.350000  67.400000
# 9423   WESTBENGAL_PURBAMEDINIPUR  2010        1  13.159783  52.790217
# 9424   WESTBENGAL_PURBAMEDINIPUR  2010        2  12.865000  51.291667
# 9425   WESTBENGAL_PURBAMEDINIPUR  2010        3  14.545833  51.550000
# 9426   WESTBENGAL_PURBAMEDINIPUR  2010        4  14.493548  51.229839
# ...
