# %%
import pandas as pd

# %%
df = pd.read_excel("TB Data.xlsx")

# %%
df.head()
# Out:
#                        STATE            DISTRICT     GEO  QTR    YR  \
# 0  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS  AN_ANI    1  2008
# 1             Andhra Pradesh            ADILABAD  AP_ADB    1  2008
# 2             Andhra Pradesh           ANANTAPUR  AP_APR    1  2008
# 3             Andhra Pradesh        BHADRACHALAM  AP_BCL    1  2008
# 4             Andhra Pradesh            CUDDAPAH  AP_CDP    1  2008
#
#    NSP Male/ NewMicConfMale  NSP Female/ NewMicConf Female  \
# 0                        37                             21
# 1                       257                            112
# 2                       529                            181
# 3                       137                             43
# 4                       296                             84
#
#    NSP Total/ NewMicConf Total  Relapse Male  Relapse Female  ...  \
# 0                           58             5               1  ...
# ...

# %%
df.columns
# Out:
# Index(['STATE', 'DISTRICT', 'GEO', 'QTR', 'YR', 'NSP Male/ NewMicConfMale',
#        'NSP Female/ NewMicConf Female', 'NSP Total/ NewMicConf Total',
#        'Relapse Male', 'Relapse Female', 'NSN Male/NewClinDiag Male',
#        'NSN Female/NewClinDiag Female', 'NEP Male', 'NEP Female',
#        'Block 1 Total Male (New & Relapse cases)',
#        'Block 1 Total Female (New & Relapse cases)',
#        'Block 1 Total (New & Relapse cases)', '0-14 yrs NSP(NewAll207+) Male',
#        '0-14 yrs NSP(NewAll207+) Female', '15-24 yrs NSP(NewAll207+) Male',
#        '15-24 yrs NSP(NewAll207+) Female', '25-34 yrs NSP(NewAll207+) Male',
#        '25-34 yrs NSP(NewAll207+) Female', '35-44 yrs NSP(NewAll207+) Male',
#        '35-44 yrs NSP(NewAll207+) Female', '45-54 yrs NSP(NewAll207+) Male',
#        '45-54 yrs NSP(NewAll207+) Female', '55-64 yrs NSP(NewAll207+) Male',
#        '55-64 yrs NSP(NewAll207+) Female',
#        '65 & above yrs NSP(NewAll207+) Male',
# ...

# %%
df1 = df.drop(['Block 1 Total Male (New & Relapse cases)' , 'Block 1 Total Female (New & Relapse cases)' , 'Block 1 Total (New & Relapse cases)' , 'NSP Block 2 Total Male' , 'NSP Block 2 Total Female' , 'NSP Block 2 Total', 'Total New',
       'Total Relapse', 'Total Failure', 'TotalTAD', 'Total Others'] , axis = 1)

# %%
df1.columns
# Out:
# Index(['STATE', 'DISTRICT', 'GEO', 'QTR', 'YR', 'NSP Male/ NewMicConfMale',
#        'NSP Female/ NewMicConf Female', 'NSP Total/ NewMicConf Total',
#        'Relapse Male', 'Relapse Female', 'NSN Male/NewClinDiag Male',
#        'NSN Female/NewClinDiag Female', 'NEP Male', 'NEP Female',
#        '0-14 yrs NSP(NewAll207+) Male', '0-14 yrs NSP(NewAll207+) Female',
#        '15-24 yrs NSP(NewAll207+) Male', '15-24 yrs NSP(NewAll207+) Female',
#        '25-34 yrs NSP(NewAll207+) Male', '25-34 yrs NSP(NewAll207+) Female',
#        '35-44 yrs NSP(NewAll207+) Male', '35-44 yrs NSP(NewAll207+) Female',
#        '45-54 yrs NSP(NewAll207+) Male', '45-54 yrs NSP(NewAll207+) Female',
#        '55-64 yrs NSP(NewAll207+) Male', '55-64 yrs NSP(NewAll207+) Female',
#        '65 & above yrs NSP(NewAll207+) Male',
#        '65 & above yrs NSP(NewAll207+) Female', 'SumOfHIV_Tested',
#        'SumOfHIV_infected'],
#       dtype='object')

# %%
pollution = pd.read_csv("pollution(2016-2018) (1).csv")

# %%
pollution.columns
# Out:
# Index(['New_name_731', 'year', 'quarter', 'so2', 'no2', 'rspm'], dtype='object')

# %%
district = pollution['New_name_731'].unique()

# %%
district
# Out:
# array(['ANDHRAPRADESH_ANANTAPUR', 'ANDHRAPRADESH_CHITTOOR',
#        'ANDHRAPRADESH_KADAPA', 'ANDHRAPRADESH_EASTGODAVARI',
#        'ANDHRAPRADESH_GUNTUR', 'TELANGANA_HYDERABAD',
#        'TELANGANA_KARIMNAGAR', 'TELANGANA_KHAMMAM',
#        'ANDHRAPRADESH_KURNOOL', 'TELANGANA_NALGONDA',
#        'ANDHRAPRADESH_SRIPOTTISRIRAMULUNELLORE', 'TELANGANA_NIZAMABAD',
#        'ANDHRAPRADESH_PRAKASAM', 'ANDHRAPRADESH_VISAKHAPATNAM',
#        'ANDHRAPRADESH_VIZIANAGARAM', 'TELANGANA_WARANGALURBAN',
#        'ANDHRAPRADESH_WESTGODAVARI', 'ARUNACHALPRADESH_PAPUMPARE',
#        'ASSAM_BONGAIGAON', 'ASSAM_CACHAR', 'ASSAM_DARRANG',
#        'ASSAM_DHEMAJI', 'ASSAM_DIBRUGARH', 'ASSAM_GOLAGHAT',
#        'ASSAM_JORHAT', 'ASSAM_KAMRUP', 'ASSAM_KARBIANGLONG',
#        'ASSAM_KARIMGANJ', 'ASSAM_LAKHIMPUR', 'ASSAM_NALBARI',
#        'ASSAM_SONITPUR', 'BIHAR_PATNA', 'BIHAR_SAMASTIPUR',
#        'CHANDIGARH_CHANDIGARH', 'CHHATTISGARH_BILASPUR',
# ...

# %%
pd.DataFrame(district).to_csv(r"Downloads/TB/FINAL/Districts.csv" , index = False)

# %%
state = df1.groupby("STATE")

# %%
andhra = state.get_group("Telangana")

# %%
upar = df1.iloc[:23718]

# %%
neeche = df1.iloc[23719:]

# %%
neeche.head()
# Out:
#                            STATE  DISTRICT  QTR  \
# 23719  Andaman & Nicobar Islands  Nicobars    1
# 23720  Andaman & Nicobar Islands  Nicobars    2
# 23721  Andaman & Nicobar Islands  Nicobars    3
# 23722  Andaman & Nicobar Islands  Nicobars    4
# 23723  Andaman & Nicobar Islands  Nicobars    1
#
#                                             YR  NSP Male/ NewMicConfMale  \
# 23719  Andaman & Nicobar IslandsNicobars2017-1                        18
# 23720  Andaman & Nicobar IslandsNicobars2017-2                        12
# 23721  Andaman & Nicobar IslandsNicobars2017-3                         6
# 23722  Andaman & Nicobar IslandsNicobars2017-4                         3
# 23723  Andaman & Nicobar IslandsNicobars2018-1                         8
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 23719                             11                           29
# 23720                              5                           17
# ...

# %%
temp = neeche['YR']

# %%
neeche['YR'] = neeche['GEO']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
neeche['GEO'] = temp
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
neeche.tail()
# Out:
#              STATE        DISTRICT   GEO  QTR    YR  NSP Male/ NewMicConfMale  \
# 29829  West Bengal  Uttar Dinajpur  2017    4  2017                       230
# 29830  West Bengal  Uttar Dinajpur  2018    1  2018                       274
# 29831  West Bengal  Uttar Dinajpur  2018    2  2018                       367
# 29832  West Bengal  Uttar Dinajpur  2018    3  2018                       319
# 29833  West Bengal  Uttar Dinajpur  2018    4  2018                       257
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 29829                             66                          296
# 29830                             99                          373
# 29831                            108                          475
# 29832                            103                          422
# 29833                             77                          334
#
#        Relapse Male  Relapse Female  ...  35-44 yrs NSP(NewAll207+) Male  \
# ...

# %%
abc = df1.iloc[23719:]

# %%
abc.head()
# Out:
#                            STATE  DISTRICT   GEO  QTR    YR  \
# 23719  Andaman & Nicobar Islands  Nicobars  2017    1  2017
# 23720  Andaman & Nicobar Islands  Nicobars  2017    2  2017
# 23721  Andaman & Nicobar Islands  Nicobars  2017    3  2017
# 23722  Andaman & Nicobar Islands  Nicobars  2017    4  2017
# 23723  Andaman & Nicobar Islands  Nicobars  2018    1  2018
#
#        NSP Male/ NewMicConfMale  NSP Female/ NewMicConf Female  \
# 23719                        18                             11
# 23720                        12                              5
# 23721                         6                              7
# 23722                         3                              2
# 23723                         8                              5
#
#        NSP Total/ NewMicConf Total  Relapse Male  Relapse Female  ...  \
# 23719                           29             4               3  ...
# 23720                           17             4               2  ...
# ...

# %%
df1.tail()
# Out:
#              STATE        DISTRICT   GEO  QTR    YR  NSP Male/ NewMicConfMale  \
# 29829  West Bengal  Uttar Dinajpur  2017    4  2017                       230
# 29830  West Bengal  Uttar Dinajpur  2018    1  2018                       274
# 29831  West Bengal  Uttar Dinajpur  2018    2  2018                       367
# 29832  West Bengal  Uttar Dinajpur  2018    3  2018                       319
# 29833  West Bengal  Uttar Dinajpur  2018    4  2018                       257
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 29829                             66                          296
# 29830                             99                          373
# 29831                            108                          475
# 29832                            103                          422
# 29833                             77                          334
#
#        Relapse Male  Relapse Female  ...  35-44 yrs NSP(NewAll207+) Male  \
# ...

# %%
df1.head()
# Out:
#                        STATE            DISTRICT     GEO  QTR    YR  \
# 0  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS  AN_ANI    1  2008
# 1             Andhra Pradesh            ADILABAD  AP_ADB    1  2008
# 2             Andhra Pradesh           ANANTAPUR  AP_APR    1  2008
# 3             Andhra Pradesh        BHADRACHALAM  AP_BCL    1  2008
# 4             Andhra Pradesh            CUDDAPAH  AP_CDP    1  2008
#
#    NSP Male/ NewMicConfMale  NSP Female/ NewMicConf Female  \
# 0                        37                             21
# 1                       257                            112
# 2                       529                            181
# 3                       137                             43
# 4                       296                             84
#
#    NSP Total/ NewMicConf Total  Relapse Male  Relapse Female  ...  \
# 0                           58             5               1  ...
# ...

# %%
neeche['YR'].iloc[:] = neeche['GEO'].iloc[:]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
neeche['GEO'].iloc[:] = temp
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
neeche.head()
# Out:
#                            STATE  DISTRICT   GEO  QTR    YR  \
# 23719  Andaman & Nicobar Islands  Nicobars  2017    1  2017
# 23720  Andaman & Nicobar Islands  Nicobars  2017    2  2017
# 23721  Andaman & Nicobar Islands  Nicobars  2017    3  2017
# 23722  Andaman & Nicobar Islands  Nicobars  2017    4  2017
# 23723  Andaman & Nicobar Islands  Nicobars  2018    1  2018
#
#        NSP Male/ NewMicConfMale  NSP Female/ NewMicConf Female  \
# 23719                        18                             11
# 23720                        12                              5
# 23721                         6                              7
# 23722                         3                              2
# 23723                         8                              5
#
#        NSP Total/ NewMicConf Total  Relapse Male  Relapse Female  ...  \
# 23719                           29             4               3  ...
# 23720                           17             4               2  ...
# ...

# %%
neeche['Temp'] = temp
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
neeche.head()
# Out:
#                            STATE  DISTRICT   GEO  QTR    YR  \
# 23719  Andaman & Nicobar Islands  Nicobars  2017    1  2017
# 23720  Andaman & Nicobar Islands  Nicobars  2017    2  2017
# 23721  Andaman & Nicobar Islands  Nicobars  2017    3  2017
# 23722  Andaman & Nicobar Islands  Nicobars  2017    4  2017
# 23723  Andaman & Nicobar Islands  Nicobars  2018    1  2018
#
#        NSP Male/ NewMicConfMale  NSP Female/ NewMicConf Female  \
# 23719                        18                             11
# 23720                        12                              5
# 23721                         6                              7
# 23722                         3                              2
# 23723                         8                              5
#
#        NSP Total/ NewMicConf Total  Relapse Male  Relapse Female  ...  \
# 23719                           29             4               3  ...
# 23720                           17             4               2  ...
# ...

# %%
neeche.rename(columns = {'GEO' : 'YR' , 'YR' : 'GEO'} , inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
neeche.head()
# Out:
#                            STATE  DISTRICT    YR  QTR  \
# 23719  Andaman & Nicobar Islands  Nicobars  2017    1
# 23720  Andaman & Nicobar Islands  Nicobars  2017    2
# 23721  Andaman & Nicobar Islands  Nicobars  2017    3
# 23722  Andaman & Nicobar Islands  Nicobars  2017    4
# 23723  Andaman & Nicobar Islands  Nicobars  2018    1
#
#                                            GEO  NSP Male/ NewMicConfMale  \
# 23719  Andaman & Nicobar IslandsNicobars2017-1                        18
# 23720  Andaman & Nicobar IslandsNicobars2017-2                        12
# 23721  Andaman & Nicobar IslandsNicobars2017-3                         6
# 23722  Andaman & Nicobar IslandsNicobars2017-4                         3
# 23723  Andaman & Nicobar IslandsNicobars2018-1                         8
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 23719                             11                           29
# ...

# %%
df1.columns
# Out:
# Index(['STATE', 'DISTRICT', 'GEO', 'QTR', 'YR', 'NSP Male/ NewMicConfMale',
#        'NSP Female/ NewMicConf Female', 'NSP Total/ NewMicConf Total',
#        'Relapse Male', 'Relapse Female', 'NSN Male/NewClinDiag Male',
#        'NSN Female/NewClinDiag Female', 'NEP Male', 'NEP Female',
#        '0-14 yrs NSP(NewAll207+) Male', '0-14 yrs NSP(NewAll207+) Female',
#        '15-24 yrs NSP(NewAll207+) Male', '15-24 yrs NSP(NewAll207+) Female',
#        '25-34 yrs NSP(NewAll207+) Male', '25-34 yrs NSP(NewAll207+) Female',
#        '35-44 yrs NSP(NewAll207+) Male', '35-44 yrs NSP(NewAll207+) Female',
#        '45-54 yrs NSP(NewAll207+) Male', '45-54 yrs NSP(NewAll207+) Female',
#        '55-64 yrs NSP(NewAll207+) Male', '55-64 yrs NSP(NewAll207+) Female',
#        '65 & above yrs NSP(NewAll207+) Male',
#        '65 & above yrs NSP(NewAll207+) Female', 'SumOfHIV_Tested',
#        'SumOfHIV_infected'],
#       dtype='object')

# %%
neeche = neeche[['STATE', 'DISTRICT', 'GEO', 'QTR', 'YR', 'NSP Male/ NewMicConfMale',
       'NSP Female/ NewMicConf Female', 'NSP Total/ NewMicConf Total',
       'Relapse Male', 'Relapse Female', 'NSN Male/NewClinDiag Male',
       'NSN Female/NewClinDiag Female', 'NEP Male', 'NEP Female',
       '0-14 yrs NSP(NewAll207+) Male', '0-14 yrs NSP(NewAll207+) Female',
       '15-24 yrs NSP(NewAll207+) Male', '15-24 yrs NSP(NewAll207+) Female',
       '25-34 yrs NSP(NewAll207+) Male', '25-34 yrs NSP(NewAll207+) Female',
       '35-44 yrs NSP(NewAll207+) Male', '35-44 yrs NSP(NewAll207+) Female',
       '45-54 yrs NSP(NewAll207+) Male', '45-54 yrs NSP(NewAll207+) Female',
       '55-64 yrs NSP(NewAll207+) Male', '55-64 yrs NSP(NewAll207+) Female',
       '65 & above yrs NSP(NewAll207+) Male',
       '65 & above yrs NSP(NewAll207+) Female', 'SumOfHIV_Tested',
       'SumOfHIV_infected']]

# %%
data = pd.concat([upar , neeche])

# %%
state = data.groupby('STATE')

# %%
andhra = state.get_group("Madhya Pradesh")

# %%
dis = andhra.groupby('DISTRICT')

# %%
cap = dis.get_group("UJJAIN")

# %%
small = dis.get_group("Ujjain")

# %%
abc = pd.concat([cap , small])

# %%
abc.to_csv(r'Downloads/TB/FINAL/Data/Madhya Pradesh/Ujjain.csv' , index = False)

# %%
andhra.to_csv(r'Downloads/TB/FINAL/Andhra.csv' , index = False)

# %%
telangana = state.get_group('Telangana')

# %%
diss = telangana.groupby('DISTRICT')

# %%
diss.get_group('Hyderabad')
# Out:
#            STATE   DISTRICT  QTR    YR  NSP Male/ NewMicConfMale  \
# 21412  Telangana  Hyderabad    1  2016                         1
# 22923  Telangana  Hyderabad    3  2016                         0
# 23611  Telangana  Hyderabad    4  2016                         0
# 28556  Telangana  Hyderabad    1  2017                       292
# 28557  Telangana  Hyderabad    2  2017                       323
# 28558  Telangana  Hyderabad    3  2017                       534
# 28559  Telangana  Hyderabad    4  2017                       664
# 28560  Telangana  Hyderabad    1  2018                       500
# 28561  Telangana  Hyderabad    2  2018                       537
# 28562  Telangana  Hyderabad    3  2018                       481
# 28563  Telangana  Hyderabad    4  2018                       534
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 21412                              0                            1
# ...

# %%
nalgonda = nalgonda[1:]

# %%
nalgonda = pd.concat([abc , nalgonda])

# %%
df1 = df1.drop('GEO' , axis= 1)

# %%
data
# Out:
#                            STATE            DISTRICT  \
# 0      Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1                 Andhra Pradesh            ADILABAD
# 2                 Andhra Pradesh           ANANTAPUR
# 3                 Andhra Pradesh        BHADRACHALAM
# 4                 Andhra Pradesh            CUDDAPAH
# ...                          ...                 ...
# 29829                West Bengal      Uttar Dinajpur
# 29830                West Bengal      Uttar Dinajpur
# 29831                West Bengal      Uttar Dinajpur
# 29832                West Bengal      Uttar Dinajpur
# 29833                West Bengal      Uttar Dinajpur
#
#                                    GEO  QTR    YR  NSP Male/ NewMicConfMale  \
# 0                               AN_ANI    1  2008                        37
# 1                               AP_ADB    1  2008                       257
# 2                               AP_APR    1  2008                       529
# ...

# %%
data = data.drop('GEO' , axis = 1)

# %%
data.to_csv(r'Downloads/TB/Final/Full_Clean.csv' , index = False)

# %%
nalgonda.to_csv(r'Downloads/TB/Final/Data/Andhra/Nalgonda.csv' , index = False)

# %%
bilaspur = dis.get_group("Bilaspur-CG")

# %%
one = abc.iloc[:24]

# %%
two = abc.iloc[24:]

# %%
qtr1 = dict(two.iloc[0])

# %%
qtr1 = pd.Series(qtr1)

# %%
one = one.append(qtr1 , ignore_index = True)

# %%
one.at[24,'QTR']= 1

# %%
one = one[:25]

# %%
abc = pd.concat([one , two])
