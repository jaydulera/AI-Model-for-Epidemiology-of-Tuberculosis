# %%
import pandas as pd

# %%
df = pd.read_csv("climate(2000-2018) (1).csv")

# %%
df.head()
# Out:
#                   Location  year  quarter  rainfall  relative_humidity  \
# 0  ANDHRAPRADESH_ANANTAPUR  2016        1      28.7          49.218217
# 1  ANDHRAPRADESH_ANANTAPUR  2005        4     168.2          84.043864
# 2  ANDHRAPRADESH_ANANTAPUR  2007        4     139.2          78.096692
# 3  ANDHRAPRADESH_ANANTAPUR  2008        4     173.3          74.431233
# 4  ANDHRAPRADESH_ANANTAPUR  2004        4      82.2          70.894351
#
#    average_temperature
# 0            22.909616
# 1            23.557007
# 2            23.739606
# 3            23.816882
# 4            23.849821

# %%
sort = df.sort_values(by=['Location' , 'year' , 'quarter'])

# %%
sort.head(30)
# Out:
#                    Location  year  quarter  rainfall  relative_humidity  \
# 25  ANDHRAPRADESH_ANANTAPUR  2000        1      36.2          46.667620
# 59  ANDHRAPRADESH_ANANTAPUR  2000        2     177.9          53.960308
# 27  ANDHRAPRADESH_ANANTAPUR  2000        3     337.1          74.711817
# 5   ANDHRAPRADESH_ANANTAPUR  2000        4     184.0          71.746896
# 35  ANDHRAPRADESH_ANANTAPUR  2001        1       5.8          40.254862
# 63  ANDHRAPRADESH_ANANTAPUR  2001        2      79.3          52.739570
# 41  ANDHRAPRADESH_ANANTAPUR  2001        3     344.8          72.144398
# 6   ANDHRAPRADESH_ANANTAPUR  2001        4     208.5          81.542333
# 24  ANDHRAPRADESH_ANANTAPUR  2002        1      16.8          50.530465
# 64  ANDHRAPRADESH_ANANTAPUR  2002        2     125.2          53.608817
# 48  ANDHRAPRADESH_ANANTAPUR  2002        3     103.1          65.227122
# 10  ANDHRAPRADESH_ANANTAPUR  2002        4      91.3          69.907763
# ...

# %%
sort.to_csv(r'Downloads/TB/Final/SortedClimate.csv' , index = False)
