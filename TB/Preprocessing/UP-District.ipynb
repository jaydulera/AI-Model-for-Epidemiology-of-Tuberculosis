# %%
import pandas as pd

# %%
df = pd.read_csv("Uttar Pradesh.csv")

# %%
df.head()
# Out:
#            STATE        DISTRICT  QTR    YR  NSP Male/ NewMicConfMale  \
# 0  Uttar Pradesh  AMBEDKAR_NAGAR    1  2008                       207
# 1  Uttar Pradesh            AGRA    1  2008                       335
# 2  Uttar Pradesh       ALLAHABAD    1  2008                       533
# 3  Uttar Pradesh         ALIGARH    1  2008                       451
# 4  Uttar Pradesh         AURAIYA    1  2008                       143
#
#    NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  NEP Male  \
# 0                             96                          303        16
# 1                            156                          491       121
# 2                            238                          771       103
# 3                            177                          628       114
# 4                             77                          220        15
#
#    NEP Female  0-14 yrs NSP(NewAll207+) Male  ...  \
# 0          25                            4.0  ...
# ...

# %%
df['DISTRICT'].unique()
# Out:
# array(['AMBEDKAR_NAGAR', 'AGRA', 'ALLAHABAD', 'ALIGARH', 'AURAIYA',
#        'AZAMGARH', 'BUDAUN', 'BALLIA', 'BARABANKI', 'BAGHPAT', 'BIJNOR',
#        'BULANDSHAHAR', 'BANDA', 'BAHRAICH', 'BAREILLY', 'BALRAMPUR',
#        'BASTI', 'CHANDAULI', 'CHITRAKOOT', 'DEORIA', 'ETAH', 'ETAWAH',
#        'FAIZABAD', 'FIROZABAD', 'FARRUKHABAD', 'FATEHPUR',
#        'GAUTAM_BUDH_NAGAR', 'GONDA', 'GORAKHPUR', 'GHAZIABAD', 'GHAZIPUR',
#        'HARDOI', 'HAMIRPUR-UP', 'HATHRAS', 'JALAUN', 'JAUNPUR', 'JHANSI',
#        'JYOTIBA_PHULE_NAGAR', 'KANNAUJ', 'KANPUR_DEHAT', 'KANPUR_NAGAR',
#        'KHERI', 'KAUSHAMBI', 'KUSHINAGAR', 'LALITPUR', 'LUCKNOW',
#        'MAINPURI', 'MAU', 'MAHOBA', 'MAHARAJGANJ', 'MORADABAD', 'MEERUT',
#        'MATHURA', 'MUZAFFARNAGAR', 'MIRZAPUR', 'PILIBHIT', 'PRATAPGARH',
#        'RAE_BARELI', 'RAMPUR', 'SONBHADRA', 'SIDDHARTHNAGAR',
#        'SHAHJAHANPUR', 'SAHARANPUR', 'SANT_KABIR_NAGAR',
#        'SANT_RAVIDAS_NAGAR', 'SHRAVASTI', 'SITAPUR', 'SULTANPUR', 'UNNAO',
# ...

# %%
h = df.groupby('DISTRICT')

# %%
cap = h.get_group('KANSHIRAM_NAGAR')

# %%
small = h.get_group('Kanshiram Nagar')

# %%
Allahabad = pd.concat([cap , small])

# %%
Allahabad.to_csv(r'Downloads/TB/Uttar Pradesh/Kanshiram Nagar (2008-2009 Missing).csv' , index = False)

# %%
Allahabad
# Out:
#               STATE         DISTRICT  QTR    YR  NSP Male/ NewMicConfMale  \
# 461   Uttar Pradesh  KANSHIRAM_NAGAR    3  2009                       152
# 532   Uttar Pradesh  KANSHIRAM_NAGAR    4  2009                       140
# 603   Uttar Pradesh  Kanshiram Nagar    1  2010                       198
# 674   Uttar Pradesh  Kanshiram Nagar    2  2010                       196
# 745   Uttar Pradesh  Kanshiram Nagar    3  2010                       163
# 816   Uttar Pradesh  Kanshiram Nagar    4  2010                       158
# 888   Uttar Pradesh  Kanshiram Nagar    1  2011                       195
# 959   Uttar Pradesh  Kanshiram Nagar    2  2011                       180
# 1030  Uttar Pradesh  Kanshiram Nagar    3  2011                       116
# 1101  Uttar Pradesh  Kanshiram Nagar    4  2011                       179
# 1171  Uttar Pradesh  Kanshiram Nagar    1  2012                       178
# 1244  Uttar Pradesh  Kanshiram Nagar    2  2012                       176
# ...

# %%
small2 = h.get_group('Hamirpur-UP')

# %%
small = pd.concat([small , small2])
