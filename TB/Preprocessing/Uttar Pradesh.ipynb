# %%
import pandas as pd

# %%
df = pd.read_excel("TB Data.xlsx")

# %%
df['STATE'].unique
# Out:
# <bound method Series.unique of 0        Andaman & Nicobar Islands
# 1                   Andhra Pradesh
# 2                   Andhra Pradesh
# 3                   Andhra Pradesh
# 4                   Andhra Pradesh
#                    ...
# 29829                  West Bengal
# 29830                  West Bengal
# 29831                  West Bengal
# 29832                  West Bengal
# 29833                  West Bengal
# Name: STATE, Length: 29834, dtype: object>

# %%
gb = df.groupby("STATE")

# %%
UP = gb.get_group("Uttar Pradesh")

# %%
UP.shape
# Out:
# (3225, 41)

# %%
UP_correct = UP[:2621]

# %%
UP_correct.tail()
# Out:
#                STATE       DISTRICT                               GEO  QTR  \
# 23679  Uttar Pradesh  Muzaffarnagar  Uttar PradeshMuzaffarnagar2016-4    4
# 23691  Uttar Pradesh      Ghaziabad      Uttar PradeshGhaziabad2016-4    4
# 23692  Uttar Pradesh         Bijnor         Uttar PradeshBijnor2016-4    4
# 23696  Uttar Pradesh     Saharanpur     Uttar PradeshSaharanpur2016-4    4
# 23697  Uttar Pradesh   Kanpur Nagar   Uttar PradeshKanpur Nagar2016-4    4
#
#          YR  NSP Male/ NewMicConfMale  NSP Female/ NewMicConf Female  \
# 23679  2016                       246                            158
# 23691  2016                       315                            238
# 23692  2016                       322                            159
# 23696  2016                       312                            181
# 23697  2016                       415                            227
#
#        NSP Total/ NewMicConf Total  Relapse Male  Relapse Female  ...  \
# ...

# %%
x = UP[2622:]

# %%
UP_wrong.head()
# Out:
#                STATE DISTRICT                      GEO  QTR  \
# 28837  Uttar Pradesh     Agra  Uttar PradeshAgra2017-1    1
# 28838  Uttar Pradesh     Agra  Uttar PradeshAgra2017-2    2
# 28839  Uttar Pradesh     Agra  Uttar PradeshAgra2017-3    3
# 28840  Uttar Pradesh     Agra  Uttar PradeshAgra2017-4    4
# 28841  Uttar Pradesh     Agra  Uttar PradeshAgra2018-1    1
#
#                             YR  NSP Male/ NewMicConfMale  \
# 28837  Uttar PradeshAgra2017-1                       311
# 28838  Uttar PradeshAgra2017-2                       340
# 28839  Uttar PradeshAgra2017-3                       241
# 28840  Uttar PradeshAgra2017-4                       234
# 28841  Uttar PradeshAgra2018-1                       484
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 28837                            184                          495
# 28838                            160                          500
# ...

# %%
UP_wrong['GEO'] , UP_wrong['YR'] = UP_wrong['YR'] , UP_wrong['GEO']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
UP_wrong.head()
# Out:
#                STATE DISTRICT                      GEO  QTR  \
# 28837  Uttar Pradesh     Agra  Uttar PradeshAgra2017-1    1
# 28838  Uttar Pradesh     Agra  Uttar PradeshAgra2017-2    2
# 28839  Uttar Pradesh     Agra  Uttar PradeshAgra2017-3    3
# 28840  Uttar Pradesh     Agra  Uttar PradeshAgra2017-4    4
# 28841  Uttar Pradesh     Agra  Uttar PradeshAgra2018-1    1
#
#                             YR  NSP Male/ NewMicConfMale  \
# 28837  Uttar PradeshAgra2017-1                       311
# 28838  Uttar PradeshAgra2017-2                       340
# 28839  Uttar PradeshAgra2017-3                       241
# 28840  Uttar PradeshAgra2017-4                       234
# 28841  Uttar PradeshAgra2018-1                       484
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 28837                            184                          495
# 28838                            160                          500
# ...

# %%
x.head()
# Out:
#                STATE DISTRICT   GEO  QTR                       YR  \
# 28837  Uttar Pradesh     Agra  2017    1  Uttar PradeshAgra2017-1
# 28838  Uttar Pradesh     Agra  2017    2  Uttar PradeshAgra2017-2
# 28839  Uttar Pradesh     Agra  2017    3  Uttar PradeshAgra2017-3
# 28840  Uttar Pradesh     Agra  2017    4  Uttar PradeshAgra2017-4
# 28841  Uttar Pradesh     Agra  2018    1  Uttar PradeshAgra2018-1
#
#        NSP Male/ NewMicConfMale  NSP Female/ NewMicConf Female  \
# 28837                       311                            184
# 28838                       340                            160
# 28839                       241                            139
# 28840                       234                            112
# 28841                       484                            229
#
#        NSP Total/ NewMicConf Total  Relapse Male  Relapse Female  ...  \
# 28837                          495            89              37  ...
# ...

# %%
UP.tail()
# Out:
#                STATE  DISTRICT   GEO  QTR                           YR  \
# 29435  Uttar Pradesh  Varanasi  2017    4  Uttar PradeshVaranasi2017-4
# 29436  Uttar Pradesh  Varanasi  2018    1  Uttar PradeshVaranasi2018-1
# 29437  Uttar Pradesh  Varanasi  2018    2  Uttar PradeshVaranasi2018-2
# 29438  Uttar Pradesh  Varanasi  2018    3  Uttar PradeshVaranasi2018-3
# 29439  Uttar Pradesh  Varanasi  2018    4  Uttar PradeshVaranasi2018-4
#
#        NSP Male/ NewMicConfMale  NSP Female/ NewMicConf Female  \
# 29435                       190                            137
# 29436                       226                            143
# 29437                       295                            199
# 29438                       275                            200
# 29439                       328                            235
#
#        NSP Total/ NewMicConf Total  Relapse Male  Relapse Female  ...  \
# 29435                          327            57              32  ...
# ...

# %%
temp = x['GEO']

# %%
x['GEO'] = x['YR']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x.head()
# Out:
#                STATE DISTRICT   GEO  QTR                       YR  \
# 28837  Uttar Pradesh     Agra  2017    1  Uttar PradeshAgra2017-1
# 28838  Uttar Pradesh     Agra  2017    2  Uttar PradeshAgra2017-2
# 28839  Uttar Pradesh     Agra  2017    3  Uttar PradeshAgra2017-3
# 28840  Uttar Pradesh     Agra  2017    4  Uttar PradeshAgra2017-4
# 28841  Uttar Pradesh     Agra  2018    1  Uttar PradeshAgra2018-1
#
#        NSP Male/ NewMicConfMale  NSP Female/ NewMicConf Female  \
# 28837                       311                            184
# 28838                       340                            160
# 28839                       241                            139
# 28840                       234                            112
# 28841                       484                            229
#
#        NSP Total/ NewMicConf Total  Relapse Male  Relapse Female  ...  \
# 28837                          495            89              37  ...
# ...

# %%
x['YR'] = temp
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x.head()
# Out:
#                STATE DISTRICT                      GEO  QTR  \
# 28837  Uttar Pradesh     Agra  Uttar PradeshAgra2017-1    1
# 28838  Uttar Pradesh     Agra  Uttar PradeshAgra2017-2    2
# 28839  Uttar Pradesh     Agra  Uttar PradeshAgra2017-3    3
# 28840  Uttar Pradesh     Agra  Uttar PradeshAgra2017-4    4
# 28841  Uttar Pradesh     Agra  Uttar PradeshAgra2018-1    1
#
#                             YR  NSP Male/ NewMicConfMale  \
# 28837  Uttar PradeshAgra2017-1                       311
# 28838  Uttar PradeshAgra2017-2                       340
# 28839  Uttar PradeshAgra2017-3                       241
# 28840  Uttar PradeshAgra2017-4                       234
# 28841  Uttar PradeshAgra2018-1                       484
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 28837                            184                          495
# 28838                            160                          500
# ...

# %%
temp
# Out:
# 28837        Uttar PradeshAgra2017-1
# 28838        Uttar PradeshAgra2017-2
# 28839        Uttar PradeshAgra2017-3
# 28840        Uttar PradeshAgra2017-4
# 28841        Uttar PradeshAgra2018-1
#                     ...
# 29435    Uttar PradeshVaranasi2017-4
# 29436    Uttar PradeshVaranasi2018-1
# 29437    Uttar PradeshVaranasi2018-2
# 29438    Uttar PradeshVaranasi2018-3
# 29439    Uttar PradeshVaranasi2018-4
# Name: GEO, Length: 603, dtype: object

# %%
x['GEO']
# Out:
# 28837    2017
# 28838    2017
# 28839    2017
# 28840    2017
# 28841    2018
#          ...
# 29435    2017
# 29436    2018
# 29437    2018
# 29438    2018
# 29439    2018
# Name: GEO, Length: 603, dtype: object

# %%
x['YR'] = x['GEO']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x.head()
# Out:
#                STATE DISTRICT   GEO  QTR    YR  NSP Male/ NewMicConfMale  \
# 28837  Uttar Pradesh     Agra  2017    1  2017                       311
# 28838  Uttar Pradesh     Agra  2017    2  2017                       340
# 28839  Uttar Pradesh     Agra  2017    3  2017                       241
# 28840  Uttar Pradesh     Agra  2017    4  2017                       234
# 28841  Uttar Pradesh     Agra  2018    1  2018                       484
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 28837                            184                          495
# 28838                            160                          500
# 28839                            139                          380
# 28840                            112                          346
# 28841                            229                          713
#
#        Relapse Male  Relapse Female  ...  NSP Block 2 Total Male  \
# ...

# %%
x.drop('GEO' , axis = 1 , inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
x.head()
# Out:
#                STATE DISTRICT  QTR    YR  NSP Male/ NewMicConfMale  \
# 28837  Uttar Pradesh     Agra    1  2017                       311
# 28838  Uttar Pradesh     Agra    2  2017                       340
# 28839  Uttar Pradesh     Agra    3  2017                       241
# 28840  Uttar Pradesh     Agra    4  2017                       234
# 28841  Uttar Pradesh     Agra    1  2018                       484
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 28837                            184                          495
# 28838                            160                          500
# 28839                            139                          380
# 28840                            112                          346
# 28841                            229                          713
#
#        Relapse Male  Relapse Female  NSN Male/NewClinDiag Male  ...  \
# 28837            89              37                        125  ...
# ...

# %%
UP_correct.tail()
# Out:
#                STATE       DISTRICT  QTR    YR  NSP Male/ NewMicConfMale  \
# 23679  Uttar Pradesh  Muzaffarnagar    4  2016                       246
# 23691  Uttar Pradesh      Ghaziabad    4  2016                       315
# 23692  Uttar Pradesh         Bijnor    4  2016                       322
# 23696  Uttar Pradesh     Saharanpur    4  2016                       312
# 23697  Uttar Pradesh   Kanpur Nagar    4  2016                       415
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 23679                            158                          404
# 23691                            238                          553
# 23692                            159                          481
# 23696                            181                          493
# 23697                            227                          642
#
#        Relapse Male  Relapse Female  NSN Male/NewClinDiag Male  ...  \
# ...

# %%
UP_correct.drop('GEO' , axis = 1 , inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
UP = pd.concat([UP_correct , x])

# %%
UP.tail()
# Out:
#                STATE  DISTRICT  QTR    YR  NSP Male/ NewMicConfMale  \
# 29435  Uttar Pradesh  Varanasi    4  2017                       190
# 29436  Uttar Pradesh  Varanasi    1  2018                       226
# 29437  Uttar Pradesh  Varanasi    2  2018                       295
# 29438  Uttar Pradesh  Varanasi    3  2018                       275
# 29439  Uttar Pradesh  Varanasi    4  2018                       328
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 29435                            137                          327
# 29436                            143                          369
# 29437                            199                          494
# 29438                            200                          475
# 29439                            235                          563
#
#        Relapse Male  Relapse Female  NSN Male/NewClinDiag Male  ...  \
# 29435            57              32                        146  ...
# ...

# %%
UP.columns
# Out:
# Index(['STATE', 'DISTRICT', 'QTR', 'YR', 'NSP Male/ NewMicConfMale',
#        'NSP Female/ NewMicConf Female', 'NSP Total/ NewMicConf Total',
#        'NEP Male', 'NEP Female', '0-14 yrs NSP(NewAll207+) Male',
#        '0-14 yrs NSP(NewAll207+) Female', '15-24 yrs NSP(NewAll207+) Male',
#        '15-24 yrs NSP(NewAll207+) Female', '25-34 yrs NSP(NewAll207+) Male',
#        '25-34 yrs NSP(NewAll207+) Female', '35-44 yrs NSP(NewAll207+) Male',
#        '35-44 yrs NSP(NewAll207+) Female', '45-54 yrs NSP(NewAll207+) Male',
#        '45-54 yrs NSP(NewAll207+) Female', '55-64 yrs NSP(NewAll207+) Male',
#        '55-64 yrs NSP(NewAll207+) Female',
#        '65 & above yrs NSP(NewAll207+) Male',
#        '65 & above yrs NSP(NewAll207+) Female', 'NSP Block 2 Total Male',
#        'NSP Block 2 Total Female', 'NSP Block 2 Total', 'Total New',
#        'Total Failure', 'SumOfHIV_Tested', 'SumOfHIV_infected'],
#       dtype='object')

# %%
UP.drop(['Relapse Male' , 'Relapse Female' , 'NSN Male/NewClinDiag Male' , 'NSN Female/NewClinDiag Female' , 'Total Relapse' , 'TotalTAD' , 'Total Others'] , axis = 1 , inplace = True)

# %%
UP.drop(['Block 1 Total Female (New & Relapse cases)' , 'Block 1 Total Male (New & Relapse cases)' ,'Block 1 Total (New & Relapse cases)' ] , axis = 1 , inplace = True)

# %%
UP.drop(['NSP Block 2 Total Male' , 'NSP Block 2 Total Male' , 'NSP Block 2 Total Female' , 'NSP Block 2 Total' ,'Total New' ] , axis = 1 , inplace = True)

# %%
UP.head()
# Out:
#              STATE        DISTRICT  QTR    YR  NSP Male/ NewMicConfMale  \
# 511  Uttar Pradesh  AMBEDKAR_NAGAR    1  2008                       207
# 512  Uttar Pradesh            AGRA    1  2008                       335
# 513  Uttar Pradesh       ALLAHABAD    1  2008                       533
# 514  Uttar Pradesh         ALIGARH    1  2008                       451
# 515  Uttar Pradesh         AURAIYA    1  2008                       143
#
#      NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  NEP Male  \
# 511                             96                          303        16
# 512                            156                          491       121
# 513                            238                          771       103
# 514                            177                          628       114
# 515                             77                          220        15
#
#      NEP Female  0-14 yrs NSP(NewAll207+) Male  ...  \
# ...

# %%
UP.columns
# Out:
# Index(['STATE', 'DISTRICT', 'QTR', 'YR', 'NSP Male/ NewMicConfMale',
#        'NSP Female/ NewMicConf Female', 'NSP Total/ NewMicConf Total',
#        'NEP Male', 'NEP Female', '0-14 yrs NSP(NewAll207+) Male',
#        '0-14 yrs NSP(NewAll207+) Female', '15-24 yrs NSP(NewAll207+) Male',
#        '15-24 yrs NSP(NewAll207+) Female', '25-34 yrs NSP(NewAll207+) Male',
#        '25-34 yrs NSP(NewAll207+) Female', '35-44 yrs NSP(NewAll207+) Male',
#        '35-44 yrs NSP(NewAll207+) Female', '45-54 yrs NSP(NewAll207+) Male',
#        '45-54 yrs NSP(NewAll207+) Female', '55-64 yrs NSP(NewAll207+) Male',
#        '55-64 yrs NSP(NewAll207+) Female',
#        '65 & above yrs NSP(NewAll207+) Male',
#        '65 & above yrs NSP(NewAll207+) Female', 'Total Failure',
#        'SumOfHIV_Tested', 'SumOfHIV_infected'],
#       dtype='object')

# %%
UP.to_csv(r'Downloads/TB/Uttar Pradesh.csv' , index = False)
