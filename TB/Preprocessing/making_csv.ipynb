# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('TB Data.xlsx')

# %%
df.head()
# Out:
#                        STATE            DISTRICT     GEO  QTR    YR  \
# 0  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS  AN_ANI    1  2008
# 1             Andhra Pradesh            ADILABAD  AP_ADB    1  2008
# 2             Andhra Pradesh           ANANTAPUR  AP_APR    1  2008
# 3             Andhra Pradesh        BHADRACHALAM  AP_BCL    1  2008
# 4             Andhra Pradesh            CUDDAPAH  AP_CDP    1  2008
#
#    NSP Male/ NewMicConfMale  NSP Female/ NewMicConf Female  \
# 0                        37                             21
# 1                       257                            112
# 2                       529                            181
# 3                       137                             43
# 4                       296                             84
#
#    NSP Total/ NewMicConf Total  Relapse Male  Relapse Female  ...  \
# 0                           58             5               1  ...
# ...

# %%
df.columns
# Out:
# Index(['STATE', 'DISTRICT', 'GEO', 'QTR', 'YR', 'NSP Male/ NewMicConfMale',
#        'NSP Female/ NewMicConf Female', 'NSP Total/ NewMicConf Total',
#        'Relapse Male', 'Relapse Female', 'NSN Male/NewClinDiag Male',
#        'NSN Female/NewClinDiag Female', 'NEP Male', 'NEP Female',
#        'Block 1 Total Male (New & Relapse cases)',
#        'Block 1 Total Female (New & Relapse cases)',
#        'Block 1 Total (New & Relapse cases)', '0-14 yrs NSP(NewAll207+) Male',
#        '0-14 yrs NSP(NewAll207+) Female', '15-24 yrs NSP(NewAll207+) Male',
#        '15-24 yrs NSP(NewAll207+) Female', '25-34 yrs NSP(NewAll207+) Male',
#        '25-34 yrs NSP(NewAll207+) Female', '35-44 yrs NSP(NewAll207+) Male',
#        '35-44 yrs NSP(NewAll207+) Female', '45-54 yrs NSP(NewAll207+) Male',
#        '45-54 yrs NSP(NewAll207+) Female', '55-64 yrs NSP(NewAll207+) Male',
#        '55-64 yrs NSP(NewAll207+) Female',
#        '65 & above yrs NSP(NewAll207+) Male',
# ...

# %%
pediatric = df['0-14 yrs NSP(NewAll207+) Male']

# %%
pediatric.head()
# Out:
# 0    0.0
# 1    3.0
# 2    2.0
# 3    0.0
# 4    0.0
# Name: 0-14 yrs NSP(NewAll207+) Male, dtype: float64

# %%
pd.concat(pediatric , df['0-14 yrs NSP(NewAll207+) Female'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-50f6b57b6e52> in <module>
# ----> 1 pd.concat(pediatric , df['0-14 yrs NSP(NewAll207+) Female'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     307                 "first argument must be an iterable of pandas "
#     308                 "objects, you passed an object of type "
# --> 309                 '"{name}"'.format(name=type(objs).__name__)
#     310             )
# ...

# %%
pediatric_f = df['0-14 yrs NSP(NewAll207+) Female']

# %%
pediatric = pd.concat([pediatric , pediatric_f] , axis = 1)

# %%
pediatric.head()
# Out:
#    0-14 yrs NSP(NewAll207+) Male  0-14 yrs NSP(NewAll207+) Female
# 0                            0.0                              2.0
# 1                            3.0                              4.0
# 2                            2.0                              3.0
# 3                            0.0                              3.0
# 4                            0.0                              2.0

# %%
year =  df['YR']

# %%
pd.concat([year , pediatric] , axis = 1 )
# Out:
#                                     YR  0-14 yrs NSP(NewAll207+) Male  \
# 0                                 2008                            0.0
# 1                                 2008                            3.0
# 2                                 2008                            2.0
# 3                                 2008                            0.0
# 4                                 2008                            0.0
# ...                                ...                            ...
# 29829  West BengalUttar Dinajpur2017-4                            0.0
# 29830  West BengalUttar Dinajpur2018-1                            3.0
# 29831  West BengalUttar Dinajpur2018-2                            3.0
# 29832  West BengalUttar Dinajpur2018-3                            1.0
# 29833  West BengalUttar Dinajpur2018-4                            0.0
#
#        0-14 yrs NSP(NewAll207+) Female
# 0                                  2.0
# 1                                  4.0
# ...

# %%
year.head(: -  1)
# Out:
#   File "<ipython-input-12-4415aa87a855>", line 1
#     year.head(: -  1)
#               ^
# SyntaxError: invalid syntax

# %%
year.tail(20)
# Out:
# 29814            West BengalTangra2018-1
# 29815            West BengalTangra2018-2
# 29816            West BengalTangra2018-3
# 29817            West BengalTangra2018-4
# 29818        West BengalTollygunge2017-1
# 29819        West BengalTollygunge2017-2
# 29820        West BengalTollygunge2017-3
# 29821        West BengalTollygunge2017-4
# 29822        West BengalTollygunge2018-1
# 29823        West BengalTollygunge2018-2
# 29824        West BengalTollygunge2018-3
# 29825        West BengalTollygunge2018-4
# 29826    West BengalUttar Dinajpur2017-1
# 29827    West BengalUttar Dinajpur2017-2
# 29828    West BengalUttar Dinajpur2017-3
# 29829    West BengalUttar Dinajpur2017-4
# 29830    West BengalUttar Dinajpur2018-1
# 29831    West BengalUttar Dinajpur2018-2
# 29832    West BengalUttar Dinajpur2018-3
# 29833    West BengalUttar Dinajpur2018-4
# Name: YR, dtype: object

# %%
df.tail()
# Out:
#              STATE        DISTRICT   GEO  QTR  \
# 29829  West Bengal  Uttar Dinajpur  2017    4
# 29830  West Bengal  Uttar Dinajpur  2018    1
# 29831  West Bengal  Uttar Dinajpur  2018    2
# 29832  West Bengal  Uttar Dinajpur  2018    3
# 29833  West Bengal  Uttar Dinajpur  2018    4
#
#                                     YR  NSP Male/ NewMicConfMale  \
# 29829  West BengalUttar Dinajpur2017-4                       230
# 29830  West BengalUttar Dinajpur2018-1                       274
# 29831  West BengalUttar Dinajpur2018-2                       367
# 29832  West BengalUttar Dinajpur2018-3                       319
# 29833  West BengalUttar Dinajpur2018-4                       257
#
#        NSP Female/ NewMicConf Female  NSP Total/ NewMicConf Total  \
# 29829                             66                          296
# 29830                             99                          373
# 29831                            108                          475
# ...

# %%
year_tail = df['GEO'].tail(6115)

# %%
year.shape
# Out:
# (29834,)

# %%
year_head = year.head(29834 - 6115)

# %%
YEAR = pd.concat([year_head , year_tail])

# %%
YEAR.shape
# Out:
# (29834,)

# %%
pd.concat([YEAR , pediatric] , axis = 1)
# Out:
#           0  0-14 yrs NSP(NewAll207+) Male  0-14 yrs NSP(NewAll207+) Female
# 0      2008                            0.0                              2.0
# 1      2008                            3.0                              4.0
# 2      2008                            2.0                              3.0
# 3      2008                            0.0                              3.0
# 4      2008                            0.0                              2.0
# ...     ...                            ...                              ...
# 29829  2017                            0.0                              2.0
# 29830  2018                            3.0                              4.0
# 29831  2018                            3.0                              2.0
# 29832  2018                            1.0                              3.0
# 29833  2018                            0.0                              2.0
#
# [29834 rows x 3 columns]

# %%
pediatric = pd.concat([df['STATE'] , df['DISTRICT'] , pediatric] , axis = 1)

# %%
pediatric.head()
# Out:
#                        STATE            DISTRICT  \
# 0  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1             Andhra Pradesh            ADILABAD
# 2             Andhra Pradesh           ANANTAPUR
# 3             Andhra Pradesh        BHADRACHALAM
# 4             Andhra Pradesh            CUDDAPAH
#
#    0-14 yrs NSP(NewAll207+) Male  0-14 yrs NSP(NewAll207+) Female
# 0                            0.0                              2.0
# 1                            3.0                              4.0
# 2                            2.0                              3.0
# 3                            0.0                              3.0
# 4                            0.0                              2.0

# %%
pediatric.tail()
# Out:
#              STATE        DISTRICT  0-14 yrs NSP(NewAll207+) Male  \
# 29829  West Bengal  Uttar Dinajpur                            0.0
# 29830  West Bengal  Uttar Dinajpur                            3.0
# 29831  West Bengal  Uttar Dinajpur                            3.0
# 29832  West Bengal  Uttar Dinajpur                            1.0
# 29833  West Bengal  Uttar Dinajpur                            0.0
#
#        0-14 yrs NSP(NewAll207+) Female
# 29829                              2.0
# 29830                              4.0
# 29831                              2.0
# 29832                              3.0
# 29833                              2.0

# %%
sum = pediatric['0-14 yrs NSP(NewAll207+) Male'] + pediatric['0-14 yrs NSP(NewAll207+) Female']

# %% [markdown]
# sum.head(

# %%
sum.head()
# Out:
# 0    2.0
# 1    7.0
# 2    5.0
# 3    3.0
# 4    2.0
# dtype: float64

# %%
pediatric['Total Pediatric'] = sum

# %%
pediatric.head()
# Out:
#                        STATE            DISTRICT  \
# 0  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1             Andhra Pradesh            ADILABAD
# 2             Andhra Pradesh           ANANTAPUR
# 3             Andhra Pradesh        BHADRACHALAM
# 4             Andhra Pradesh            CUDDAPAH
#
#    0-14 yrs NSP(NewAll207+) Male  0-14 yrs NSP(NewAll207+) Female  \
# 0                            0.0                              2.0
# 1                            3.0                              4.0
# 2                            2.0                              3.0
# 3                            0.0                              3.0
# 4                            0.0                              2.0
#
#    Total Pediatric
# 0              2.0
# 1              7.0
# 2              5.0
# 3              3.0
# 4              2.0

# %%
pd.concat([Yea])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-5a72755a9489> in <module>
# ----> 1 pd.concat([Yea])
#
# NameError: name 'Yea' is not defined

# %%
pediatric.head()
# Out:
#                        STATE            DISTRICT  \
# 0  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1             Andhra Pradesh            ADILABAD
# 2             Andhra Pradesh           ANANTAPUR
# 3             Andhra Pradesh        BHADRACHALAM
# 4             Andhra Pradesh            CUDDAPAH
#
#    0-14 yrs NSP(NewAll207+) Male  0-14 yrs NSP(NewAll207+) Female  \
# 0                            0.0                              2.0
# 1                            3.0                              4.0
# 2                            2.0                              3.0
# 3                            0.0                              3.0
# 4                            0.0                              2.0
#
#    Total Pediatric
# 0              2.0
# 1              7.0
# 2              5.0
# 3              3.0
# 4              2.0

# %%
pediatric = pd.concat([YEAR , pediatric] , axis = 1)

# %%
pediatric.head()
# Out:
#       0                      STATE            DISTRICT  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1  2008             Andhra Pradesh            ADILABAD
# 2  2008             Andhra Pradesh           ANANTAPUR
# 3  2008             Andhra Pradesh        BHADRACHALAM
# 4  2008             Andhra Pradesh            CUDDAPAH
#
#    0-14 yrs NSP(NewAll207+) Male  0-14 yrs NSP(NewAll207+) Female  \
# 0                            0.0                              2.0
# 1                            3.0                              4.0
# 2                            2.0                              3.0
# 3                            0.0                              3.0
# 4                            0.0                              2.0
#
#    Total Pediatric
# 0              2.0
# 1              7.0
# 2              5.0
# 3              3.0
# 4              2.0

# %%
pediatric.rename(columns={0 : 'Year'} , inplace=True)

# %%
pediatric.head()
# Out:
#    Year                      STATE            DISTRICT  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1  2008             Andhra Pradesh            ADILABAD
# 2  2008             Andhra Pradesh           ANANTAPUR
# 3  2008             Andhra Pradesh        BHADRACHALAM
# 4  2008             Andhra Pradesh            CUDDAPAH
#
#    0-14 yrs NSP(NewAll207+) Male  0-14 yrs NSP(NewAll207+) Female  \
# 0                            0.0                              2.0
# 1                            3.0                              4.0
# 2                            2.0                              3.0
# 3                            0.0                              3.0
# 4                            0.0                              2.0
#
#    Total Pediatric
# 0              2.0
# 1              7.0
# 2              5.0
# 3              3.0
# 4              2.0

# %%
geriatric = df[['65 & above yrs NSP(NewAll207+) Male' , '65 & above yrs NSP(NewAll207+) Female']]

# %%
geriatric.head()
# Out:
#    65 & above yrs NSP(NewAll207+) Male  65 & above yrs NSP(NewAll207+) Female
# 0                                  2.0                                    2.0
# 1                                 24.0                                    5.0
# 2                                 53.0                                    5.0
# 3                                  5.0                                    4.0
# 4                                 33.0                                    3.0

# %%
sum = df['65 & above yrs NSP(NewAll207+) Male'] + df['65 & above yrs NSP(NewAll207+) Female']

# %%
sum.head()
# Out:
# 0     4.0
# 1    29.0
# 2    58.0
# 3     9.0
# 4    36.0
# dtype: float64

# %%
geriatric['Total Geriatric'] = sum
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
geriatric.head()
# Out:
#    65 & above yrs NSP(NewAll207+) Male  65 & above yrs NSP(NewAll207+) Female  \
# 0                                  2.0                                    2.0
# 1                                 24.0                                    5.0
# 2                                 53.0                                    5.0
# 3                                  5.0                                    4.0
# 4                                 33.0                                    3.0
#
#    Total Geriatric
# 0              4.0
# 1             29.0
# 2             58.0
# 3              9.0
# 4             36.0

# %%
pd.concat([pediatric['YEAR'] , pediatric['STATE'] , pediatric['DISTRICT'] , geriatric] , axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YEAR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-655b6f5821bf> in <module>
# ...

# %%
geriatric_h = pediatric.drop(['Total Pediatric' , '0-14 yrs NSP(NewAll207+) Male' , '0-14 yrs NSP(NewAll207+) Female'] , axis = 1)

# %% [raw]
# eh

# %%
geriatric_h.head()
# Out:
#    Year                      STATE            DISTRICT
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1  2008             Andhra Pradesh            ADILABAD
# 2  2008             Andhra Pradesh           ANANTAPUR
# 3  2008             Andhra Pradesh        BHADRACHALAM
# 4  2008             Andhra Pradesh            CUDDAPAH

# %%
geriatric = pd.concat([geriatric_h , geriatric] , axis = 1)

# %%
geriatric.head()
# Out:
#    Year                      STATE            DISTRICT  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1  2008             Andhra Pradesh            ADILABAD
# 2  2008             Andhra Pradesh           ANANTAPUR
# 3  2008             Andhra Pradesh        BHADRACHALAM
# 4  2008             Andhra Pradesh            CUDDAPAH
#
#    65 & above yrs NSP(NewAll207+) Male  65 & above yrs NSP(NewAll207+) Female  \
# 0                                  2.0                                    2.0
# 1                                 24.0                                    5.0
# 2                                 53.0                                    5.0
# 3                                  5.0                                    4.0
# 4                                 33.0                                    3.0
#
#    Total Geriatric
# 0              4.0
# 1             29.0
# 2             58.0
# 3              9.0
# 4             36.0

# %%
h = df[['SumOfHIV_Tested' , 'SumOfHIV_infected']]

# %%
h.head()
# Out:
#    SumOfHIV_Tested  SumOfHIV_infected
# 0              0.0                0.0
# 1            177.0               76.0
# 2            199.0               50.0
# 3             89.0                7.0
# 4              0.0                0.0

# %%
HIV = pd.concat([geriatric_h , h] , axis = 1)

# %%
HIV.head()
# Out:
#    Year                      STATE            DISTRICT  SumOfHIV_Tested  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS              0.0
# 1  2008             Andhra Pradesh            ADILABAD            177.0
# 2  2008             Andhra Pradesh           ANANTAPUR            199.0
# 3  2008             Andhra Pradesh        BHADRACHALAM             89.0
# 4  2008             Andhra Pradesh            CUDDAPAH              0.0
#
#    SumOfHIV_infected
# 0                0.0
# 1               76.0
# 2               50.0
# 3                7.0
# 4                0.0

# %%
HIV.to_csv(r'Downloads/HIV.csv')

# %%
pediatric.to_csv(r'Downloads/Pediatric.csv')

# %%
geriatric.to_csv(r'Downloads/Geriatric.csv')

# %%
pediatric['Quarter'] = df['QTR']

# %%
pediatric.head()
# Out:
#    Year                      STATE            DISTRICT  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1  2008             Andhra Pradesh            ADILABAD
# 2  2008             Andhra Pradesh           ANANTAPUR
# 3  2008             Andhra Pradesh        BHADRACHALAM
# 4  2008             Andhra Pradesh            CUDDAPAH
#
#    0-14 yrs NSP(NewAll207+) Male  0-14 yrs NSP(NewAll207+) Female  \
# 0                            0.0                              2.0
# 1                            3.0                              4.0
# 2                            2.0                              3.0
# 3                            0.0                              3.0
# 4                            0.0                              2.0
#
#    Total Pediatric  Quarter
# 0              2.0        1
# 1              7.0        1
# 2              5.0        1
# 3              3.0        1
# 4              2.0        1

# %%
geriatric['Quarter'] = df['QTR']

# %%
geriatric.head()
# Out:
#    Year                      STATE            DISTRICT  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS
# 1  2008             Andhra Pradesh            ADILABAD
# 2  2008             Andhra Pradesh           ANANTAPUR
# 3  2008             Andhra Pradesh        BHADRACHALAM
# 4  2008             Andhra Pradesh            CUDDAPAH
#
#    65 & above yrs NSP(NewAll207+) Male  65 & above yrs NSP(NewAll207+) Female  \
# 0                                  2.0                                    2.0
# 1                                 24.0                                    5.0
# 2                                 53.0                                    5.0
# 3                                  5.0                                    4.0
# 4                                 33.0                                    3.0
#
#    Total Geriatric  Quarter
# 0              4.0        1
# 1             29.0        1
# 2             58.0        1
# 3              9.0        1
# ...

# %%
HIV['Quarter'] = df['QTR']

# %%
HIV.head()
# Out:
#    Year                      STATE            DISTRICT  SumOfHIV_Tested  \
# 0  2008  Andaman & Nicobar Islands  ANDAMAN_NICOBAR_IS              0.0
# 1  2008             Andhra Pradesh            ADILABAD            177.0
# 2  2008             Andhra Pradesh           ANANTAPUR            199.0
# 3  2008             Andhra Pradesh        BHADRACHALAM             89.0
# 4  2008             Andhra Pradesh            CUDDAPAH              0.0
#
#    SumOfHIV_infected  Quarter
# 0                0.0        1
# 1               76.0        1
# 2               50.0        1
# 3                7.0        1
# 4                0.0        1

# %%
HIV.to_csv(r'Downloads/HIV.csv' , index=False)

# %%
pediatric.to_csv(r'Downloads/Pediatric.csv' , index = False)

# %%
geriatric.to_csv(r'Downloads/Geriatric.csv' , index = False)
